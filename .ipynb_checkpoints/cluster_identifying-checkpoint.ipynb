# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score## Loading credentials from another config file

# %% [markdown]
# ## Loading credentials from another config file

# %%
import config

# %% [markdown]
# ## Starting with Spotify API

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %% [markdown]
# ## Searching the song input by user

# %%
user_song = 'Perfect'

# %%
results = sp.search(q = user_song, limit = 30, market="GB")
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Perfect&type=track&market=GB&offset=0&limit=30',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#      'href': 'https://api.spotify.com/v1/albums/3T4tUhGYeRNVUGevb0wThu',
#      'id': '3T4tUhGYeRNVUGevb0wThu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ba5db46f4b838ef6027e6f96',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ba5db46f4b838ef6027e6f96',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ba5db46f4b838ef6027e6f96',
#        'width': 64}],
#      'name': '÷ (Deluxe)',
#      'release_date': '2017-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:3T4tUhGYeRNVUGevb0wThu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 263400,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1700024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0tgVpDi06FyKpA1z0VMD4v'},
#     'href': 'https://api.spotify.com/v1/tracks/0tgVpDi06FyKpA1z0VMD4v',
#     'id': '0tgVpDi06FyKpA1z0VMD4v',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect',
#     'popularity': 85,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a929516d1cc57de66ae18e7d02d0673147a305d9?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0tgVpDi06FyKpA1z0VMD4v'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4uJ318DIOMiA4y9vg2dRwv'},
#      'href': 'https://api.spotify.com/v1/albums/4uJ318DIOMiA4y9vg2dRwv',
#      'id': '4uJ318DIOMiA4y9vg2dRwv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a629dbc92d4dcb0312b45fa2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a629dbc92d4dcb0312b45fa2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a629dbc92d4dcb0312b45fa2',
#        'width': 64}],
#      'name': 'Perfect (Acoustic)',
#      'release_date': '2017-11-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4uJ318DIOMiA4y9vg2dRwv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 260866,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1701083'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5T6bJp3XgwT0IaCfKMxmAu'},
#     'href': 'https://api.spotify.com/v1/tracks/5T6bJp3XgwT0IaCfKMxmAu',
#     'id': '5T6bJp3XgwT0IaCfKMxmAu',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect - Acoustic',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5d910d6a3f3452133f818ca90f4ccc025cd2b39d?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5T6bJp3XgwT0IaCfKMxmAu'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6RTov0UzyIyfpbear2uznQ'},
#      'href': 'https://api.spotify.com/v1/albums/6RTov0UzyIyfpbear2uznQ',
#      'id': '6RTov0UzyIyfpbear2uznQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273356310716d7639a96709371a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02356310716d7639a96709371a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851356310716d7639a96709371a',
#        'width': 64}],
#      'name': 'Just Chill Easy Hits',
#      'release_date': '2023-02-17',
#      'release_date_precision': 'day',
#      'total_tracks': 70,
#      'type': 'album',
#      'uri': 'spotify:album:6RTov0UzyIyfpbear2uznQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 263400,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1700024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1akSe0eMHxz4GXVfCfXofN'},
#     'href': 'https://api.spotify.com/v1/tracks/1akSe0eMHxz4GXVfCfXofN',
#     'id': '1akSe0eMHxz4GXVfCfXofN',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9f56c08eb8c921458e9c92d1104b45f8b4ac1408?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1akSe0eMHxz4GXVfCfXofN'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4hmztbSs72tNbQigiDjfJm'},
#      'href': 'https://api.spotify.com/v1/albums/4hmztbSs72tNbQigiDjfJm',
#      'id': '4hmztbSs72tNbQigiDjfJm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27370e09d3478857e1fe3a93b81',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0270e09d3478857e1fe3a93b81',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485170e09d3478857e1fe3a93b81',
#        'width': 64}],
#      'name': 'Soft 10s',
#      'release_date': '2023-02-17',
#      'release_date_precision': 'day',
#      'total_tracks': 42,
#      'type': 'album',
#      'uri': 'spotify:album:4hmztbSs72tNbQigiDjfJm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 263400,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1700024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3sy0xtBmZP6jQphjohJh9N'},
#     'href': 'https://api.spotify.com/v1/tracks/3sy0xtBmZP6jQphjohJh9N',
#     'id': '3sy0xtBmZP6jQphjohJh9N',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7507171d452b88a6efc14b9932d9543cec658d8d?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:3sy0xtBmZP6jQphjohJh9N'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7riQPkkGZBnTh9ve5qIhYo'},
#        'href': 'https://api.spotify.com/v1/artists/7riQPkkGZBnTh9ve5qIhYo',
#        'id': '7riQPkkGZBnTh9ve5qIhYo',
#        'name': 'Mareux',
#        'type': 'artist',
#        'uri': 'spotify:artist:7riQPkkGZBnTh9ve5qIhYo'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2JnZQM70jbT0J1Xq0qgl24'},
#      'href': 'https://api.spotify.com/v1/albums/2JnZQM70jbT0J1Xq0qgl24',
#      'id': '2JnZQM70jbT0J1Xq0qgl24',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733d54a30e59638f60f56dd4e6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023d54a30e59638f60f56dd4e6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513d54a30e59638f60f56dd4e6',
#        'width': 64}],
#      'name': 'The Perfect Girl',
#      'release_date': '2021-12-08',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2JnZQM70jbT0J1Xq0qgl24'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7riQPkkGZBnTh9ve5qIhYo'},
#       'href': 'https://api.spotify.com/v1/artists/7riQPkkGZBnTh9ve5qIhYo',
#       'id': '7riQPkkGZBnTh9ve5qIhYo',
#       'name': 'Mareux',
#       'type': 'artist',
#       'uri': 'spotify:artist:7riQPkkGZBnTh9ve5qIhYo'}],
#     'disc_number': 1,
#     'duration_ms': 194423,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZF8N1986577'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5RBOcBpJXaNnHCGViJmYhh'},
#     'href': 'https://api.spotify.com/v1/tracks/5RBOcBpJXaNnHCGViJmYhh',
#     'id': '5RBOcBpJXaNnHCGViJmYhh',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'The Perfect Girl',
#     'popularity': 79,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e46e44586efb402745ce1ed132582dc10e3a4fb5?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5RBOcBpJXaNnHCGViJmYhh'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#        'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#        'id': '6vWDO969PvNqNYHIOW5v0m',
#        'name': 'Beyoncé',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/52kvZcbEDm0v2kWZQXjuuA'},
#      'href': 'https://api.spotify.com/v1/albums/52kvZcbEDm0v2kWZQXjuuA',
#      'id': '52kvZcbEDm0v2kWZQXjuuA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273af6b2fca3b6e24612a5fe5d8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02af6b2fca3b6e24612a5fe5d8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851af6b2fca3b6e24612a5fe5d8',
#        'width': 64}],
#      'name': 'Perfect Duet (Ed Sheeran & Beyoncé)',
#      'release_date': '2017-11-30',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:52kvZcbEDm0v2kWZQXjuuA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'disc_number': 1,
#     'duration_ms': 259550,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1701196'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1bhUWB0zJMIKr9yVPrkEuI'},
#     'href': 'https://api.spotify.com/v1/tracks/1bhUWB0zJMIKr9yVPrkEuI',
#     'id': '1bhUWB0zJMIKr9yVPrkEuI',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect Duet (Ed Sheeran & Beyoncé)',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e1e6dbd4c799b84db6229841d0c45971c2de72fd?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1bhUWB0zJMIKr9yVPrkEuI'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4AK6F7OLvEQ5QYCBNiQWHq'},
#        'href': 'https://api.spotify.com/v1/artists/4AK6F7OLvEQ5QYCBNiQWHq',
#        'id': '4AK6F7OLvEQ5QYCBNiQWHq',
#        'name': 'One Direction',
#        'type': 'artist',
#        'uri': 'spotify:artist:4AK6F7OLvEQ5QYCBNiQWHq'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1gMxiQQSg5zeu4htBosASY'},
#      'href': 'https://api.spotify.com/v1/albums/1gMxiQQSg5zeu4htBosASY',
#      'id': '1gMxiQQSg5zeu4htBosASY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273241e4fe75732c9c4b49b94c3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02241e4fe75732c9c4b49b94c3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851241e4fe75732c9c4b49b94c3',
#        'width': 64}],
#      'name': 'Made In The A.M. (Deluxe Edition)',
#      'release_date': '2015-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:1gMxiQQSg5zeu4htBosASY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4AK6F7OLvEQ5QYCBNiQWHq'},
#       'href': 'https://api.spotify.com/v1/artists/4AK6F7OLvEQ5QYCBNiQWHq',
#       'id': '4AK6F7OLvEQ5QYCBNiQWHq',
#       'name': 'One Direction',
#       'type': 'artist',
#       'uri': 'spotify:artist:4AK6F7OLvEQ5QYCBNiQWHq'}],
#     'disc_number': 1,
#     'duration_ms': 230333,
#     'explicit': False,
#     'external_ids': {'isrc': 'G
},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4W12lEvVl5wectUtRNrvDh'},
#        'href': 'https://api.spotify.com/v1/artists/4W12lEvVl5wectUtRNrvDh',
#        'id': '4W12lEvVl5wectUtRNrvDh',
#        'name': 'White Noise Baby Sleep',
#        'type': 'artist',
#        'uri': 'spotify:artist:4W12lEvVl5wectUtRNrvDh'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2jw2gGOljFXbX480sW6SxL'},
#      'href': 'https://api.spotify.com/v1/albums/2jw2gGOljFXbX480sW6SxL',
#      'id': '2jw2gGOljFXbX480sW6SxL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27392283de8621426ca03b8360a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0292283de8621426ca03b8360a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485192283de8621426ca03b8360a',
#        'width': 64}],
#      'name': 'White Noise for Sleeping Babies',
#      'release_date': '2015-03-27',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:2jw2gGOljFXbX480sW6SxL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4W12lEvVl5wectUtRNrvDh'},
#       'href': 'https://api.spotify.com/v1/artists/4W12lEvVl5wectUtRNrvDh',
#       'id': '4W12lEvVl5wectUtRNrvDh',
#       'name': 'White Noise Baby Sleep',
#       'type': 'artist',
#       'uri': 'spotify:artist:4W12lEvVl5wectUtRNrvDh'}],
#     'disc_number': 1,
#     'duration_ms': 596886,
#     'explicit': False,
#     'external_ids': {'isrc': 'uscgj1524697'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/26SAfHmtlIP2pZVASwtloc'},
#     'href': 'https://api.spotify.com/v1/tracks/26SAfHmtlIP2pZVASwtloc',
#     'id': '26SAfHmtlIP2pZVASwtloc',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect Natural White Noise as a Relaxing Ambient Sleep Aid (Nice Lullaby)',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9ab33749dbe45a306a4b3c5f1da6b9bc1b4d004c?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:26SAfHmtlIP2pZVASwtloc'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/14vm7o0onJik95uZlnRs4G'},
#      'href': 'https://api.spotify.com/v1/albums/14vm7o0onJik95uZlnRs4G',
#      'id': '14vm7o0onJik95uZlnRs4G',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ebb70ee379d58b041ccbff76',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ebb70ee379d58b041ccbff76',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ebb70ee379d58b041ccbff76',
#        'width': 64}],
#      'name': 'Liefdesliedjes 2023',
#      'release_date': '2023-02-17',
#      'release_date_precision': 'day',
#      'total_tracks': 42,
#      'type': 'album',
#      'uri': 'spotify:album:14vm7o0onJik95uZlnRs4G'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 263400,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1700024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2egUTRdnncu6vFLXD92VmW'},
#     'href': 'https://api.spotify.com/v1/tracks/2egUTRdnncu6vFLXD92VmW',
#     'id': '2egUTRdnncu6vFLXD92VmW',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9f56c08eb8c921458e9c92d1104b45f8b4ac1408?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2egUTRdnncu6vFLXD92VmW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HBjj22wzbscIZ9sEb5dyf'},
#        'href': 'https://api.spotify.com/v1/artists/1HBjj22wzbscIZ9sEb5dyf',
#        'id': '1HBjj22wzbscIZ9sEb5dyf',
#        'name': 'Jonas Blue',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HBjj22wzbscIZ9sEb5dyf'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2xZSrcBmvMw9Y8hac6xU7L'},
#      'href': 'https://api.spotify.com/v1/albums/2xZSrcBmvMw9Y8hac6xU7L',
#      'id': '2xZSrcBmvMw9Y8hac6xU7L',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735b6bcc59c3562a6f362344c6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025b6bcc59c3562a6f362344c6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515b6bcc59c3562a6f362344c6',
#        'width': 64}],
#      'name': 'Blue',
#      'release_date': '2018-11-09',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:2xZSrcBmvMw9Y8hac6xU7L'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HBjj22wzbscIZ9sEb5dyf'},
#       'href': 'https://api.spotify.com/v1/artists/1HBjj22wzbscIZ9sEb5dyf',
#       'id': '1HBjj22wzbscIZ9sEb5dyf',
#       'name': 'Jonas Blue',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HBjj22wzbscIZ9sEb5dyf'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYGAK2zu9EAomwj3hXkXy'},
#       'href': 'https://api.spotify.com/v1/artists/4kYGAK2zu9EAomwj3hXkXy',
#       'id': '4kYGAK2zu9EAomwj3hXkXy',
#       'name': 'JP Cooper',
#       'type': 'artist',
#       'uri': 'spotify:artist:4kYGAK2zu9EAomwj3hXkXy'}],
#     'disc_number': 1,
#     'duration_ms': 196613,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71602437'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3P3pw6C19j31Rnzgo3JG7o'},
#     'href': 'https://api.spotify.com/v1/tracks/3P3pw6C19j31Rnzgo3JG7o',
#     'id': '3P3pw6C19j31Rnzgo3JG7o',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect Strangers',
#     'popularity': 71,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3c480508bddca3a7e54679175c75fcc7db279639?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3P3pw6C19j31Rnzgo3JG7o'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KpCz7V5XRkqKuM1JDf56O'},
#        'href': 'https://api.spotify.com/v1/artists/0KpCz7V5XRkqKuM1JDf56O',
#        'id': '0KpCz7V5XRkqKuM1JDf56O',
#        'name': 'Cousin Stizz',
#        'type': 'artist',
#        'uri': 'spotify:artist:0KpCz7V5XRkqKuM1JDf56O'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2S5f607kus6aZo5UcA3gPS'},
#      'href': 'https://api.spotify.com/v1/albums/2S5f607kus6aZo5UcA3gPS',
#      'id': '2S5f607kus6aZo5UcA3gPS',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27350dfdb0c16b97eae828e0c10',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0250dfdb0c16b97eae828e0c10',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485150dfdb0c16b97eae828e0c10',
#        'width': 64}],
#      'name': 'Perfect (Remix) (feat. Doja Cat & BIA)',
#      'release_date': '2020-02-14',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2S5f607kus6aZo5UcA3gPS'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KpCz7V5XRkqKuM1JDf56O'},
#       'href': 'https://api.spotify.com/v1/artists/0KpCz7V5XRkqKuM1JDf56O',
#       'id': '0KpCz7V5XRkqKuM1JDf56O',
#       'name': 'Cousin Stizz',
#       'type': 'artist',
#       'uri': 'spotify:artist:0KpCz7V5XRkqKuM1JDf56O'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#       'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#       'id': '5cj0lLjcoR7YOSnhnX0Po5',
#       'name': 'Doja Cat',
#       'type': 'artist',
#       'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6veh5zbFpm31XsPdjBgPER'},
#       'href': 'https://api.spotify.com/v1/artists/6veh5zbFpm31XsPdjBgPER',
#       'id': '6veh5zbFpm31XsPdjBgPER',
#       'name': 'BIA',
#       'type': 'artist',
#       'uri': 'spotify:artist:6veh5zbFpm31XsPdjBgPER'}],
#     'disc_number': 1,
#     'duration_ms': 197461,
#     'explicit': True,
#     'external_ids': {'isrc': 'USRC12000521'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/31tgCy8mn6sFuIiHSHfEhm'},
#     'href': 'https://api.spotify.com/v1/tracks/31tgCy8mn6sFuIiHSHfEhm',
#     'id': '31tgCy8mn6sFuIiHSHfEhm',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect (Remix) (feat. Doja Cat & BIA)',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/91a2667b65e7a6a8b4259791a78054502d4ee5c4?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:31tgCy8mn6sFuIiHSHfEhm'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5vg48e8MBFXHfUO4yT5ELM'},
#      'href': 'https://api.spotify.com/v1/albums/5vg48e8MBFXHfUO4yT5ELM',
#      'id': '5vg48e8MBFXHfUO4yT5ELM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273da31bc3dce7de67eda5513df',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02da31bc3dce7de67eda5513df',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851da31bc3dce7de67eda5513df',
#        'width': 64}],
#      'name': 'All Day Throwback 100 Hits',
#      'release_date': '2023-02-17',
#      'release_date_precision': 'day',
#      'total_tracks': 100,
#      'type': 'album',
#      'uri': 'spotify:album:5vg48e8MBFXHfUO4yT5ELM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 263400,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1700024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7gcmx3WiyZDcUoLXE6B5EW'},
#     'href': 'https://api.spotify.com/v1/tracks/7gcmx3WiyZDcUoLXE6B5EW',
#     'id': '7gcmx3WiyZDcUoLXE6B5EW',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9f56c08eb8c921458e9c92d1104b45f8b4ac1408?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:7gcmx3WiyZDcUoLXE6B5EW'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2m1anAOoOQM3Df2j3tNelS'},
#        'href': 'https://api.spotify.com/v1/artists/2m1anAOoOQM3Df2j3tNelS',
#        'id': '2m1anAOoOQM3Df2j3tNelS',
#        'name': 'Powell Sullivan',
#        'type': 'artist',
#        'uri': 'spotify:artist:2m1anAOoOQM3Df2j3tNelS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2fYaBSkUVlzK5nTDxLYMZ3'},
#      'href': 'https://api.spotify.com/v1/albums/2fYaBSkUVlzK5nTDxLYMZ3',
#      'id': '2fYaBSkUVlzK5nTDxLYMZ3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273215d7425b938aa01663055cd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02215d7425b938aa01663055cd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851215d7425b938aa01663055cd',
#        'width': 64}],
#      'name': 'Perfect',
#      'release_date': '2017-11-08',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2fYaBSkUVlzK5nTDxLYMZ3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2m1anAOoOQM3Df2j3tNelS'},
#       'href': 'https://api.spotify.com/v1/artists/2m1anAOoOQM3Df2j3tNelS',
#       'id': '2m1anAOoOQM3Df2j3tNelS',
#       'name': 'Powell Sullivan',
#       'type': 'artist',
#       'uri': 'spotify:artist:2m1anAOoOQM3Df2j3tNelS'}],
#     'disc_number': 1,
#     'duration_ms': 281302,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5IB1701954'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7mFKhrFYjNsC2IMHCMzsDg'},
#     'href': 'https://api.spotify.com/v1/tracks/7mFKhrFYjNsC2IMHCMzsDg',
#     'id': '7mFKhrFYjNsC2IMHCMzsDg',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect',
#     'popularity': 44,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cf31816594472de8c663eb506d4ae95f88e27c0e?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7mFKhrFYjNsC2IMHCMzsDg'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7mpuCc5RJrH5047X6M7Rcd'},
#        'href': 'https://api.spotify.com/v1/artists/7mpuCc5RJrH5047X6M7Rcd',
#        'id': '7mpuCc5RJrH5047X6M7Rcd',
#        'name': 'Mundo Suave',
#        'type': 'artist',
#        'uri': 'spotify:artist:7mpuCc5RJrH5047X6M7Rcd'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/25nMYJeMnGslko2C1Id5ps'},
#      'href': 'https://api.spotify.com/v1/albums/25nMYJeMnGslko2C1Id5ps',
#      'id': '25nMYJeMnGslko2C1Id5ps',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27346d93e643b46c2762eb6cad3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0246d93e643b46c2762eb6cad3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485146d93e643b46c2762eb6cad3',
#        'width': 64}],
#      'name': 'Perfection',
#      'release_date': '2022-11-18',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:25nMYJeMnGslko2C1Id5ps'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7mpuCc5RJrH5047X6M7Rcd'},
#       'href': 'https://api.spotify.com/v1/artists/7mpuCc5RJrH5047X6M7Rcd',
#       'id': '7mpuCc5RJrH5047X6M7Rcd',
#       'name': 'Mundo Suave',
#       'type': 'artist',
#       'uri': 'spotify:artist:7mpuCc5RJrH5047X6M7Rcd'}],
#     'disc_number': 1,
#     'duration_ms': 174314,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE6RB2205128'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1b6zd9iiSYGSCz5tYW14l6'},
#     'href': 'https://api.spotify.com/v1/tracks/1b6zd9iiSYGSCz5tYW14l6',
#     'id': '1b6zd9iiSYGSCz5tYW14l6',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfection',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/72eeb7fdcc2ab56230aee2cabcc1f05ad68f8f3c?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1b6zd9iiSYGSCz5tYW14l6'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/69rLxJE2m7eQCR043Ri0Qt'},
#      'href': 'https://api.spotify.com/v1/albums/69rLxJE2m7eQCR043Ri0Qt',
#      'id': '69rLxJE2m7eQCR043Ri0Qt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27348b7ff9eb2149150a7a14a5a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0248b7ff9eb2149150a7a14a5a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485148b7ff9eb2149150a7a14a5a',
#        'width': 64}],
#      'name': '7 Years - Pop Classics',
#      'release_date': '2023-02-17',
#      'release_date_precision': 'day',
#      'total_tracks': 32,
#      'type': 'album',
#      'uri': 'spotify:album:69rLxJE2m7eQCR043Ri0Qt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 263400,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1700024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2lXhc3MDr6owK5S8ivUNEr'},
#     'href': 'https://api.spotify.com/v1/tracks/2lXhc3MDr6owK5S8ivUNEr',
#     'id': '2lXhc3MDr6owK5S8ivUNEr',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9f56c08eb8c921458e9c92d1104b45f8b4ac1408?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:2lXhc3MDr6owK5S8ivUNEr'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/42TFhl7WlMRXiNqzSrnzPL'},
#        'href': 'https://api.spotify.com/v1/artists/42TFhl7WlMRXiNqzSrnzPL',
#        'id': '42TFhl7WlMRXiNqzSrnzPL',
#        'name': 'Lou Reed',
#        'type': 'artist',
#        'uri': 'spotify:artist:42TFhl7WlMRXiNqzSrnzPL'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5SqbMEyAt8332ISGiLX0St'},
#      'href': 'https://api.spotify.com/v1/albums/5SqbMEyAt8332ISGiLX0St',
#      'id': '5SqbMEyAt8332ISGiLX0St',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d55149748dca0e5a1f40778e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d55149748dca0e5a1f40778e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d55149748dca0e5a1f40778e',
#        'width': 64}],
#      'name': 'Transformer',
#      'release_date': '1972-12-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:5SqbMEyAt8332ISGiLX0St'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/42TFhl7WlMRXiNqzSrnzPL'},
#       'href': 'https://api.spotify.com/v1/artists/42TFhl7WlMRXiNqzSrnzPL',
#       'id': '42TFhl7WlMRXiNqzSrnzPL',
#       'name': 'Lou Reed',
#       'type': 'artist',
#       'uri': 'spotify:artist:42TFhl7WlMRXiNqzSrnzPL'}],
#     'disc_number': 1,
#     'duration_ms': 225000,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC17201946'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4TOMI010Sd4ZAX4aZ5TS85'},
#     'href': 'https://api.spotify.com/v1/tracks/4TOMI010Sd4ZAX4aZ5TS85',
#     'id': '4TOMI010Sd4ZAX4aZ5TS85',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect Day',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cf07629eb4361b31f923b4eedfe928a7e4138288?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:4TOMI010Sd4ZAX4aZ5TS85'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3ZQ5TYGh6ei3IDnQ3GscGh'},
#      'href': 'https://api.spotify.com/v1/albums/3ZQ5TYGh6ei3IDnQ3GscGh',
#      'id': '3ZQ5TYGh6ei3IDnQ3GscGh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27312edfb2f917ca8d3436fb047',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0212edfb2f917ca8d3436fb047',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485112edfb2f917ca8d3436fb047',
#        'width': 64}],
#      'name': 'Perfect (Mike Perry Remix)',
#      'release_date': '2017-11-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3ZQ5TYGh6ei3IDnQ3GscGh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6lB8vOoI4DRrrVxXwuV19c'},
#       'href': 'https://api.spotify.com/v1/artists/6lB8vOoI4DRrrVxXwuV19c',
#       'id': '6lB8vOoI4DRrrVxXwuV19c',
#       'name': 'Mike Perry',
#       'type': 'artist',
#       'uri': 'spotify:artist:6lB8vOoI4DRrrVxXwuV19c'}],
#     'disc_number': 1,
#     'duration_ms': 221332,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1701146'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5AJgjETGRZMlONKiKzYCUy'},
#     'href': 'https://api.spotify.com/v1/tracks/5AJgjETGRZMlONKiKzYCUy',
#     'id': '5AJgjETGRZMlONKiKzYCUy',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect - Mike Perry Remix',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/59c1696698c6021059d92e7e90c8a1819a83e4c4?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5AJgjETGRZMlONKiKzYCUy'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fomCZiFUMX73KJ0YQ0V90'},
#        'href': 'https://api.spotify.com/v1/artists/4fomCZiFUMX73KJ0YQ0V90',
#        'id': '4fomCZiFUMX73KJ0YQ0V90',
#        'name': 'The Beautiful South',
#        'type': 'artist',
#        'uri': 'spotify:artist:4fomCZiFUMX73KJ0YQ0V90'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4z0lsUMEXG9X7cT2YPzmjg'},
#      'href': 'https://api.spotify.com/v1/albums/4z0lsUMEXG9X7cT2YPzmjg',
#      'id': '4z0lsUMEXG9X7cT2YPzmjg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f6d0dd7232e493681a4dd230',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f6d0dd7232e493681a4dd230',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f6d0dd7232e493681a4dd230',
#        'width': 64}],
#      'name': 'Quench',
#      'release_date': '1998-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:4z0lsUMEXG9X7cT2YPzmjg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fomCZiFUMX73KJ0YQ0V90'},
#       'href': 'https://api.spotify.com/v1/artists/4fomCZiFUMX73KJ0YQ0V90',
#       'id': '4fomCZiFUMX73KJ0YQ0V90',
#       'name': 'The Beautiful South',
#       'type': 'artist',
#       'uri': 'spotify:artist:4fomCZiFUMX73KJ0YQ0V90'}],
#     'disc_number': 1,
#     'duration_ms': 218626,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAQT9800006'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Eejw1SOBhHt7RjWJH7onO'},
#     'href': 'https://api.spotify.com/v1/tracks/2Eejw1SOBhHt7RjWJH7onO',
#     'id': '2Eejw1SOBhHt7RjWJH7onO',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect 10',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c84494494bbe9a0c721b12c95f01190813d0fdc8?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:2Eejw1SOBhHt7RjWJH7onO'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3AXe7WcqDsjgchcm3BQsB5'},
#      'href': 'https://api.spotify.com/v1/albums/3AXe7WcqDsjgchcm3BQsB5',
#      'id': '3AXe7WcqDsjgchcm3BQsB5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27308c52babf038e98acb876e5d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0208c52babf038e98acb876e5d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485108c52babf038e98acb876e5d',
#        'width': 64}],
#      'name': 'At My Worst: Chilled Pop',
#      'release_date': '2023-02-15',
#      'release_date_precision': 'day',
#      'total_tracks': 49,
#      'type': 'album',
#      'uri': 'spotify:album:3AXe7WcqDsjgchcm3BQsB5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 263400,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1700024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4Sh1oIB47h9RsO4exiYwR6'},
#     'href': 'https://api.spotify.com/v1/tracks/4Sh1oIB47h9RsO4exiYwR6',
#     'id': '4Sh1oIB47h9RsO4exiYwR6',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9f56c08eb8c921458e9c92d1104b45f8b4ac1408?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:4Sh1oIB47h9RsO4exiYwR6'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0jW6R8CVyVohuUJVcuweDI'},
#        'href': 'https://api.spotify.com/v1/artists/0jW6R8CVyVohuUJVcuweDI',
#        'id': '0jW6R8CVyVohuUJVcuweDI',
#        'name': 'The Piano Guys',
#        'type': 'artist',
#        'uri': 'spotify:artist:0jW6R8CVyVohuUJVcuweDI'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/34MK1MIhRB9evwfomSyMig'},
#      'href': 'https://api.spotify.com/v1/albums/34MK1MIhRB9evwfomSyMig',
#      'id': '34MK1MIhRB9evwfomSyMig',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27389a018e0e2e48f01c3afe2fd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0289a018e0e2e48f01c3afe2fd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485189a018e0e2e48f01c3afe2fd',
#        'width': 64}],
#      'name': 'Perfect',
#      'release_date': '2017-07-21',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:34MK1MIhRB9evwfomSyMig'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0jW6R8CVyVohuUJVcuweDI'},
#       'href': 'https://api.spotify.com/v1/artists/0jW6R8CVyVohuUJVcuweDI',
#       'id': '0jW6R8CVyVohuUJVcuweDI',
#       'name': 'The Piano Guys',
#       'type': 'artist',
#       'uri': 'spotify:artist:0jW6R8CVyVohuUJVcuweDI'}],
#     'disc_number': 1,
#     'duration_ms': 310798,
#     'explicit': False,
#     'external_ids': {'isrc': 'USQX91701532'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2R0FW1n6cOkQDJhAkQENsf'},
#     'href': 'https://api.spotify.com/v1/tracks/2R0FW1n6cOkQDJhAkQENsf',
#     'id': '2R0FW1n6cOkQDJhAkQENsf',
# ...
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ffa1f1633575a72236b30793',
#        'width': 64}],
#      'name': 'Sleep Baby Sleep',
#      'release_date': '2019-01-25',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:7e3Q5458201As9Ed7mFANg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0MvSBMGRQJY3mRwIbJsqF1'},
#       'href': 'https://api.spotify.com/v1/artists/0MvSBMGRQJY3mRwIbJsqF1',
#       'id': '0MvSBMGRQJY3mRwIbJsqF1',
#       'name': 'Royal Philharmonic Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:0MvSBMGRQJY3mRwIbJsqF1'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7mC0zQ4J4cJPNGYFlmiQVC'},
#       'href': 'https://api.spotify.com/v1/artists/7mC0zQ4J4cJPNGYFlmiQVC',
#       'id': '7mC0zQ4J4cJPNGYFlmiQVC',
#       'name': 'James Morgan',
#       'type': 'artist',
#       'uri': 'spotify:artist:7mC0zQ4J4cJPNGYFlmiQVC'}],
#     'disc_number': 1,
#     'duration_ms': 283675,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBPGU1800074'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/56K2M8iU9JWVZpPKqfXxZ3'},
#     'href': 'https://api.spotify.com/v1/tracks/56K2M8iU9JWVZpPKqfXxZ3',
#     'id': '56K2M8iU9JWVZpPKqfXxZ3',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect',
#     'popularity': 5,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c1cc20363c143793afc5c859fd52242661ed3567?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:56K2M8iU9JWVZpPKqfXxZ3'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6g6NVjkCHREmXuV8R4m9Wu'},
#      'href': 'https://api.spotify.com/v1/albums/6g6NVjkCHREmXuV8R4m9Wu',
#      'id': '6g6NVjkCHREmXuV8R4m9Wu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c12abd69bce7cde233015421',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c12abd69bce7cde233015421',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c12abd69bce7cde233015421',
#        'width': 64}],
#      'name': 'Jerusalema: Modern Hits',
#      'release_date': '2023-02-15',
#      'release_date_precision': 'day',
#      'total_tracks': 60,
#      'type': 'album',
#      'uri': 'spotify:album:6g6NVjkCHREmXuV8R4m9Wu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 263400,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1700024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2U012DLF3DvfBEsVvNqbVd'},
#     'href': 'https://api.spotify.com/v1/tracks/2U012DLF3DvfBEsVvNqbVd',
#     'id': '2U012DLF3DvfBEsVvNqbVd',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9f56c08eb8c921458e9c92d1104b45f8b4ac1408?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2U012DLF3DvfBEsVvNqbVd'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7riQPkkGZBnTh9ve5qIhYo'},
#        'href': 'https://api.spotify.com/v1/artists/7riQPkkGZBnTh9ve5qIhYo',
#        'id': '7riQPkkGZBnTh9ve5qIhYo',
#        'name': 'Mareux',
#        'type': 'artist',
#        'uri': 'spotify:artist:7riQPkkGZBnTh9ve5qIhYo'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Oa32CWdPcsW36MkDRjM5n'},
#        'href': 'https://api.spotify.com/v1/artists/2Oa32CWdPcsW36MkDRjM5n',
#        'id': '2Oa32CWdPcsW36MkDRjM5n',
#        'name': 'The Motion',
#        'type': 'artist',
#        'uri': 'spotify:artist:2Oa32CWdPcsW36MkDRjM5n'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6LtIcRhkNqGdXl2OESjDPE'},
#      'href': 'https://api.spotify.com/v1/albums/6LtIcRhkNqGdXl2OESjDPE',
#      'id': '6LtIcRhkNqGdXl2OESjDPE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27315b3b77a593667d8121f6fbf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0215b3b77a593667d8121f6fbf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485115b3b77a593667d8121f6fbf',
#        'width': 64}],
#      'name': 'The Perfect Girl (The Motion Retrowave Remix)',
#      'release_date': '2022-05-16',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:6LtIcRhkNqGdXl2OESjDPE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7riQPkkGZBnTh9ve5qIhYo'},
#       'href': 'https://api.spotify.com/v1/artists/7riQPkkGZBnTh9ve5qIhYo',
#       'id': '7riQPkkGZBnTh9ve5qIhYo',
#       'name': 'Mareux',
#       'type': 'artist',
#       'uri': 'spotify:artist:7riQPkkGZBnTh9ve5qIhYo'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Oa32CWdPcsW36MkDRjM5n'},
#       'href': 'https://api.spotify.com/v1/artists/2Oa32CWdPcsW36MkDRjM5n',
#       'id': '2Oa32CWdPcsW36MkDRjM5n',
#       'name': 'The Motion',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Oa32CWdPcsW36MkDRjM5n'}],
#     'disc_number': 1,
#     'duration_ms': 181016,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12201788'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1UcyzhmBDfdw07DiuT7DEG'},
#     'href': 'https://api.spotify.com/v1/tracks/1UcyzhmBDfdw07DiuT7DEG',
#     'id': '1UcyzhmBDfdw07DiuT7DEG',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'The Perfect Girl - The Motion Retrowave Remix',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/678f49a67e44091c47481745d74c13c47489cc65?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1UcyzhmBDfdw07DiuT7DEG'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7DSyG9R0sNgPndQjjTIgRn'},
#        'href': 'https://api.spotify.com/v1/artists/7DSyG9R0sNgPndQjjTIgRn',
#        'id': '7DSyG9R0sNgPndQjjTIgRn',
#        'name': 'SlowFez',
#        'type': 'artist',
#        'uri': 'spotify:artist:7DSyG9R0sNgPndQjjTIgRn'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/12k0uC5ep47JT6wnL0CdvD'},
#      'href': 'https://api.spotify.com/v1/albums/12k0uC5ep47JT6wnL0CdvD',
#      'id': '12k0uC5ep47JT6wnL0CdvD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739da857e9a492f54d5cc03ce6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029da857e9a492f54d5cc03ce6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519da857e9a492f54d5cc03ce6',
#        'width': 64}],
#      'name': 'Perfect - Slowed',
#      'release_date': '2022-03-05',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:12k0uC5ep47JT6wnL0CdvD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7DSyG9R0sNgPndQjjTIgRn'},
#       'href': 'https://api.spotify.com/v1/artists/7DSyG9R0sNgPndQjjTIgRn',
#       'id': '7DSyG9R0sNgPndQjjTIgRn',
#       'name': 'SlowFez',
#       'type': 'artist',
#       'uri': 'spotify:artist:7DSyG9R0sNgPndQjjTIgRn'}],
#     'disc_number': 1,
#     'duration_ms': 238848,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM4TX2210824'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/10d7J9AezQDWNpbjcr6qXy'},
#     'href': 'https://api.spotify.com/v1/tracks/10d7J9AezQDWNpbjcr6qXy',
#     'id': '10d7J9AezQDWNpbjcr6qXy',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect - Slowed',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/94bc27c3888bb4df75c87aac6bd13c4c20564ab3?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:10d7J9AezQDWNpbjcr6qXy'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#        'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#        'id': '2wY79sveU1sp5g7SokKOiI',
#        'name': 'Sam Smith',
#        'type': 'artist',
#        'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3Uq1jNGnD412ZvCb6j2DKV'},
#      'href': 'https://api.spotify.com/v1/albums/3Uq1jNGnD412ZvCb6j2DKV',
#      'id': '3Uq1jNGnD412ZvCb6j2DKV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fc3ff54493fcc890bcaa036c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fc3ff54493fcc890bcaa036c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fc3ff54493fcc890bcaa036c',
#        'width': 64}],
#      'name': 'Gloria',
#      'release_date': '2023-01-27',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:3Uq1jNGnD412ZvCb6j2DKV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#       'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#       'id': '2wY79sveU1sp5g7SokKOiI',
#       'name': 'Sam Smith',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3KedxarmBCyFBevnqQHy3P'},
#       'href': 'https://api.spotify.com/v1/artists/3KedxarmBCyFBevnqQHy3P',
#       'id': '3KedxarmBCyFBevnqQHy3P',
#       'name': 'Jessie Reyez',
#       'type': 'artist',
#       'uri': 'spotify:artist:3KedxarmBCyFBevnqQHy3P'}],
#     'disc_number': 1,
#     'duration_ms': 231592,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM72205414'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0mL3oQwd5ZoLDpdoVuzrbg'},
#     'href': 'https://api.spotify.com/v1/tracks/0mL3oQwd5ZoLDpdoVuzrbg',
#     'id': '0mL3oQwd5ZoLDpdoVuzrbg',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect (feat. Jessie Reyez)',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b2d98e52aa90287b16c3de031dc5e1117bf90b60?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0mL3oQwd5ZoLDpdoVuzrbg'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6S183X2AUTWpO6unjuiJ7T'},
#      'href': 'https://api.spotify.com/v1/albums/6S183X2AUTWpO6unjuiJ7T',
#      'id': '6S183X2AUTWpO6unjuiJ7T',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736594cf5d04f66c1f2544c23f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026594cf5d04f66c1f2544c23f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516594cf5d04f66c1f2544c23f',
#        'width': 64}],
#      'name': 'Chill Songs Everyone Knows',
#      'release_date': '2023-02-17',
#      'release_date_precision': 'day',
#      'total_tracks': 37,
#      'type': 'album',
#      'uri': 'spotify:album:6S183X2AUTWpO6unjuiJ7T'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 263400,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1700024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1DHTfk8FwmWNzSh1nLmkRS'},
#     'href': 'https://api.spotify.com/v1/tracks/1DHTfk8FwmWNzSh1nLmkRS',
#     'id': '1DHTfk8FwmWNzSh1nLmkRS',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9f56c08eb8c921458e9c92d1104b45f8b4ac1408?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 23,
#     'type': 'track',
#     'uri': 'spotify:track:1DHTfk8FwmWNzSh1nLmkRS'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Riv2KnFcLZA3JSVryRg4y'},
#        'href': 'https://api.spotify.com/v1/artists/0Riv2KnFcLZA3JSVryRg4y',
#        'id': '0Riv2KnFcLZA3JSVryRg4y',
#        'name': 'Hiroyuki Sawano',
#        'type': 'artist',
#        'uri': 'spotify:artist:0Riv2KnFcLZA3JSVryRg4y'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4OHuwh9kd4b38gyrP5YMmP'},
#      'href': 'https://api.spotify.com/v1/albums/4OHuwh9kd4b38gyrP5YMmP',
#      'id': '4OHuwh9kd4b38gyrP5YMmP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273141f3f80e8ad1721000083a9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02141f3f80e8ad1721000083a9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851141f3f80e8ad1721000083a9',
#        'width': 64}],
#      'name': '七つの大罪 オリジナル・サウンドトラック',
#      'release_date': '2014-12-24',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:4OHuwh9kd4b38gyrP5YMmP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Riv2KnFcLZA3JSVryRg4y'},
#       'href': 'https://api.spotify.com/v1/artists/0Riv2KnFcLZA3JSVryRg4y',
#       'id': '0Riv2KnFcLZA3JSVryRg4y',
#       'name': 'Hiroyuki Sawano',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Riv2KnFcLZA3JSVryRg4y'}],
#     'disc_number': 1,
#     'duration_ms': 283760,
#     'explicit': False,
#     'external_ids': {'isrc': 'JPE301401275'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1upmGVmHvx0MEHEVdvnBCK'},
#     'href': 'https://api.spotify.com/v1/tracks/1upmGVmHvx0MEHEVdvnBCK',
#     'id': '1upmGVmHvx0MEHEVdvnBCK',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect Time',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5cf909a40e45e93268e69dfceb72aa530fab0ac7?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1upmGVmHvx0MEHEVdvnBCK'}],
#   'limit': 30,
#   'next': 'https://api.spotify.com/v1/search?query=Perfect&type=track&market=GB&offset=30&limit=30',
#   'offset': 0,
#   'previous': None,
#   'total': 1000}}

# %%
artist_list = []
for i in range(len(results['tracks']['items'])):
    artist_list.append(results['tracks']['items'][i]['artists'][0]['name'])

# %%
artist_list = list(set(artist_list))

# %%
artist_list.remove('Ed Sheeran')

# %%
artist_list
# Out:
# ['Sam Smith',
#  'SlowFez',
#  'One Direction',
#  'Hiroyuki Sawano',
#  'Powell Sullivan',
#  'The Beautiful South',
#  'White Noise Baby Sleep',
#  'Lou Reed',
#  'Jonas Blue',
#  'Mareux',
#  'Ghost and Pals',
#  'Mundo Suave',
#  'Cousin Stizz']

# %%
# Identify artist
user_song_artist = results['tracks']['items'][0]['artists'][0]['name']

# %%
# Identify track ID
user_song_id = results['tracks']['items'][0]['id']

# %%
# Get audio features of this song
user_song_features = sp.audio_features(tracks=[user_song_id])

# %%
# Save the features in a dataframe
user_song_raw_df = pd.DataFrame(user_song_features)
user_song_df = user_song_raw_df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","duration_ms"]]
user_song_df
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.599   0.448    -6.312       0.0232         0.163
#
#    instrumentalness  liveness  valence  tempo  duration_ms
# 0                 0     0.106    0.168  95.05       263400

# %% [markdown]
# ## Applying Model

# %% [markdown]
# ## Doading Dataset

# %%
X = pd.read_csv('data/playlists.csv')

# %%
X
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.707   0.681    -4.325       0.0668       0.06320
# 1            0.644   0.735    -5.747       0.0391       0.05210
# 2            0.696   0.809    -8.254       0.0500       0.25200
# 3            0.538   0.742    -5.355       0.1140       0.13800
# 4            0.662   0.398    -6.691       0.0275       0.71600
# ...            ...     ...       ...          ...           ...
# 2418         0.636   0.656    -7.123       0.3440       0.02190
# 2419         0.753   0.424   -10.620       0.5990       0.19700
# 2420         0.501   0.699    -4.733       0.2480       0.17100
# 2421         0.645   0.842    -3.023       0.0983       0.00816
# 2422         0.902   0.544    -8.242       0.2420       0.15300
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000005    0.0322    0.646  117.999  0yLdNVWF3Srea0uzk55zFn
# 1             0.144000    0.1610    0.418   88.980  1Qrg8KqiBpW07V7PNxwwwL
# 2             0.000128    0.2480    0.857  132.962  6AQbmUe0Qwf5PZnt4HmTXv
# 3             0.000047    0.0934    0.250   96.107  5Z2MiIZ5I3jJvvmeWMLbOQ
# 4             0.000000    0.1110    0.468  107.001  4sx6NRwL6Ol3V6m9exwGlQ
# ...                ...       ...      ...      ...                     ...
# 2418          0.000000    0.1300    0.362   75.962  2nLwnTorexhx3qKRY7zymH
# 2419          0.000000    0.0694    0.714  162.878  5ckdswsm7RQzCTBoNiyl7T
# 2420          0.000000    0.1230    0.671   85.267  7rGzPK1JTUn91efeiIidNo
# 2421          0.000000    0.3960    0.237  150.039  2kMuUWfsueRPYWxyaTSHd8
# 2422          0.000000    0.1110    0.136  131.912  7b4LMdMrjPLNUNwxO46sQR
#
#       duration_ms
# 0          200455
# 1          153947
# 2          131013
# 3          272373
# 4          145850
# ...           ...
# 2418       177012
# 2419       100180
# 2420       201124
# 2421       121600
# 2422       160000
#
# [2423 rows x 11 columns]

# %%
# Extract numerical cols
X_num = X.select_dtypes(include=['float64', 'int64'])

# %%
X_num
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.707   0.681    -4.325       0.0668       0.06320
# 1            0.644   0.735    -5.747       0.0391       0.05210
# 2            0.696   0.809    -8.254       0.0500       0.25200
# 3            0.538   0.742    -5.355       0.1140       0.13800
# 4            0.662   0.398    -6.691       0.0275       0.71600
# ...            ...     ...       ...          ...           ...
# 2418         0.636   0.656    -7.123       0.3440       0.02190
# 2419         0.753   0.424   -10.620       0.5990       0.19700
# 2420         0.501   0.699    -4.733       0.2480       0.17100
# 2421         0.645   0.842    -3.023       0.0983       0.00816
# 2422         0.902   0.544    -8.242       0.2420       0.15300
#
#       instrumentalness  liveness  valence    tempo  duration_ms
# 0             0.000005    0.0322    0.646  117.999       200455
# 1             0.144000    0.1610    0.418   88.980       153947
# 2             0.000128    0.2480    0.857  132.962       131013
# 3             0.000047    0.0934    0.250   96.107       272373
# 4             0.000000    0.1110    0.468  107.001       145850
# ...                ...       ...      ...      ...          ...
# 2418          0.000000    0.1300    0.362   75.962       177012
# 2419          0.000000    0.0694    0.714  162.878       100180
# 2420          0.000000    0.1230    0.671   85.267       201124
# 2421          0.000000    0.3960    0.237  150.039       121600
# 2422          0.000000    0.1110    0.136  131.912       160000
#
# [2423 rows x 10 columns]

# %% [markdown]
# ## Scaling features

# %%
scaler = StandardScaler()
scaler.fit(X_num)
X_scaled = scaler.transform(X_num)
X_scaled_df = pd.DataFrame(X_scaled, columns = X_num.columns)
display(X_num.head())
print()
display(X_scaled_df.head())
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.707   0.681    -4.325       0.0668        0.0632
# 1         0.644   0.735    -5.747       0.0391        0.0521
# 2         0.696   0.809    -8.254       0.0500        0.2520
# 3         0.538   0.742    -5.355       0.1140        0.1380
# 4         0.662   0.398    -6.691       0.0275        0.7160
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000005    0.0322    0.646  117.999       200455
# 1          0.144000    0.1610    0.418   88.980       153947
# 2          0.000128    0.2480    0.857  132.962       131013
# 3          0.000047    0.0934    0.250   96.107       272373
# 4          0.000000    0.1110    0.468  107.001       145850
#    danceability    energy  loudness  speechiness  acousticness  \
# 0      0.596043  0.433025  0.774695    -0.334403     -0.787999
# 1      0.228609  0.635469  0.585278    -0.574993     -0.819821
# 2      0.531888  0.912893  0.251333    -0.480320     -0.246737
# 3     -0.389612  0.661712  0.637494     0.075556     -0.573558
# 4      0.333590 -0.627934  0.459532    -0.675745      1.083483
#
#    instrumentalness  liveness   valence     tempo  duration_ms
# 0         -0.448685 -1.051603  0.552641 -0.025989    -0.005247
# 1          0.002294 -0.029185 -0.365433 -1.011085    -0.778662
# 2         -0.448300  0.661424  1.402261  0.481953    -1.160048
# 3         -0.448555 -0.565795 -1.041908 -0.769147     1.190730
# 4         -0.448701 -0.426086 -0.164101 -0.399334    -0.913313

# %% [markdown]
# # Clustering the tracks with K-Means

# %%
kmeans = KMeans(n_clusters = 6, random_state = 1234)
kmeans.fit(X_scaled_df)
# Out:
# KMeans(n_clusters=6, random_state=1234)

# %%
kmeans.labels_
# Out:
# array([5, 5, 5, ..., 3, 4, 3], dtype=int32)

# %%
# assign a cluster to each example
labels = kmeans.predict(X_scaled_df)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(X.to_numpy()[row_ix, 1], X.to_numpy()[row_ix, 3])
# show the plot
pyplot.show()

# %% [markdown]
# ## Identify Cluster of User's Song

# %%
# Scale features of user song
user_scaled = scaler.transform(user_song_df)
user_scaled_df = pd.DataFrame(user_scaled, columns = user_song_df.columns)
user_scaled_df
# Out:
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -0.033843 -0.440486  0.510017    -0.713093     -0.501887
#
#    instrumentalness  liveness   valence     tempo  duration_ms
# 0         -0.448701 -0.465776 -1.372093 -0.805029     1.041512

# %%
# Get the cluster label of user song
user_cluster = kmeans.predict(user_scaled_df)

user_cluster_num = user_cluster[0]

# %% [markdown]
# ## Choosing a Song from the Identified Cluster

# %%
X_clustered = pd.read_csv('data/playlists_clustered.csv')

# %%
X_clustered
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.707   0.681    -4.325       0.0668       0.06320
# 1            0.644   0.735    -5.747       0.0391       0.05210
# 2            0.696   0.809    -8.254       0.0500       0.25200
# 3            0.538   0.742    -5.355       0.1140       0.13800
# 4            0.662   0.398    -6.691       0.0275       0.71600
# ...            ...     ...       ...          ...           ...
# 2418         0.636   0.656    -7.123       0.3440       0.02190
# 2419         0.753   0.424   -10.620       0.5990       0.19700
# 2420         0.501   0.699    -4.733       0.2480       0.17100
# 2421         0.645   0.842    -3.023       0.0983       0.00816
# 2422         0.902   0.544    -8.242       0.2420       0.15300
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000005    0.0322    0.646  117.999  0yLdNVWF3Srea0uzk55zFn
# 1             0.144000    0.1610    0.418   88.980  1Qrg8KqiBpW07V7PNxwwwL
# 2             0.000128    0.2480    0.857  132.962  6AQbmUe0Qwf5PZnt4HmTXv
# 3             0.000047    0.0934    0.250   96.107  5Z2MiIZ5I3jJvvmeWMLbOQ
# 4             0.000000    0.1110    0.468  107.001  4sx6NRwL6Ol3V6m9exwGlQ
# ...                ...       ...      ...      ...                     ...
# 2418          0.000000    0.1300    0.362   75.962  2nLwnTorexhx3qKRY7zymH
# 2419          0.000000    0.0694    0.714  162.878  5ckdswsm7RQzCTBoNiyl7T
# 2420          0.000000    0.1230    0.671   85.267  7rGzPK1JTUn91efeiIidNo
# 2421          0.000000    0.3960    0.237  150.039  2kMuUWfsueRPYWxyaTSHd8
# 2422          0.000000    0.1110    0.136  131.912  7b4LMdMrjPLNUNwxO46sQR
#
#       duration_ms  cluster
# 0          200455        5
# 1          153947        5
# 2          131013        5
# 3          272373        2
# 4          145850        0
# ...           ...      ...
# 2418       177012        3
# 2419       100180        3
# 2420       201124        3
# 2421       121600        4
# 2422       160000        3
#
# [2423 rows x 12 columns]

# %%
import random
# Filter out rows where cluster == user_cluster_num
rec_df = X_clustered[X_clustered['cluster'] == user_cluster_num]

# %%
rec_df
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 3            0.538   0.742    -5.355       0.1140      0.138000
# 9            0.714   0.472    -7.375       0.0864      0.013000
# 15           0.486   0.545    -7.924       0.0336      0.065200
# 16           0.559   0.551    -7.231       0.1320      0.141000
# 25           0.587   0.742    -6.640       0.0529      0.012800
# ...            ...     ...       ...          ...           ...
# 2332         0.719   0.655    -4.519       0.0999      0.202000
# 2344         0.762   0.634    -6.790       0.1260      0.073700
# 2386         0.834   0.730    -3.714       0.2220      0.005130
# 2403         0.729   0.625    -5.266       0.0315      0.194000
# 2413         0.477   0.727    -4.053       0.2860      0.000866
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 3             0.000047    0.0934   0.2500   96.107  5Z2MiIZ5I3jJvvmeWMLbOQ
# 9             0.000005    0.2660   0.2380  131.121  3nqQXoyQOWXiESFLlDF1hG
# 15            0.004740    0.0642   0.0385  150.187  4FyesJzVpA39hbYvcseO2d
# 16            0.000000    0.1100   0.3920  143.008  4iZ4pt7kvcaH6Yo8UoZ4s2
# 25            0.001070    0.1460   0.1990  145.007  73vIOb4Q7YN6HeJTbscRx5
# ...                ...       ...      ...      ...                     ...
# 2332          0.000000    0.1570   0.2380  125.925  6QC19cMrtbLNrZMH2bVl7w
# 2344          0.000000    0.0758   0.2080   93.127  5sm3g5UwuDnzKN91T5elip
# 2386          0.000000    0.1240   0.4460  155.008  2xLMifQCjDGFmkHkpNLD9h
# 2403          0.009860    0.2480   0.2610  146.034  1xzBco0xcoJEDXktl7Jxrr
# 2413          0.000000    0.1080   0.2270  150.062  1EJIcDYXwSqipW5dFe4uJz
#
#       duration_ms  cluster
# 3          272373        2
# 9          156943        2
# 15         123891        2
# 16         201800        2
# 25         206000        2
# ...           ...      ...
# 2332       233226        2
# 2344       247742        2
# 2386       312820        2
# 2403       183907        2
# 2413       236524        2
#
# [454 rows x 12 columns]

# %%
import random
# Randomly select one row from the filtered DataFrame
rec_row = rec_df.sample(random_state=1)

# %%
rec_id = X_clustered[X_clustered['cluster'] == user_cluster_num].sample()['id'].values[0]
rec_id
# Out:
# '3FAclTFfvUuQYnEsptbK8w'

# %% [markdown]
# ## Embeded track player

# %% [markdown]
# {'spotify': https://open.spotify.com/track/4O2N861eOnF9q8EtpH8IJu

# %%
from IPython.display import IFrame

def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
play_song(rec_id)
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3FAclTFfvUuQYnEsptbK8w?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Incoperating the Inputting Function

# %%
# %pip install fuzzywuzzy
from fuzzywuzzy import fuzz
from IPython.display import IFrame
# Out:
# Requirement already satisfied: fuzzywuzzy in /Users/marcelzhang/opt/anaconda3/lib/python3.9/site-packages (0.18.0)
# Note: you may need to restart the kernel to use updated packages.
# /Users/marcelzhang/opt/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# ### Preparing the Dataframe for the Billboard 100 List

# %%
# Import the dataframe of Billboard 100
hot = pd.read_csv('data/billboards_100.csv')

# %%
hot
# Out:
#                            song                                artist
# 0                       Flowers                           Miley Cyrus
# 1                     Kill Bill                                   SZA
# 2                    Last Night                         Morgan Wallen
# 3                        Unholy                Sam Smith & Kim Petras
# 4                      Creepin'  Metro Boomin, The Weeknd & 21 Savage
# ..                          ...                                   ...
# 95                   Yandel 150                         Yandel & Feid
# 96               Heart To Heart                           Mac DeMarco
# 97          Next Thing You Know                          Jordan Davis
# 98  Never Gonna Not Dance Again                                  P!nk
# 99                    Open Arms            SZA Featuring Travis Scott
#
# [100 rows x 2 columns]

# %%
# Assign each artist to a seperate column 
hot_split = hot.rename(columns = {'artist': 'artist_1'})
hot_split = hot_split.assign(artist_2=hot_split['artist_1'].str.split(',| & | With | Featuring | x | X ', expand=True)[1],
                             artist_3=hot_split['artist_1'].str.split(',| & | With | Featuring | x | X ', expand=True)[2])
hot_split['artist_1'] = hot_split['artist_1'].str.split(',| & | With | Featuring | x | X ', expand=True).iloc[:, 0]

# %%
hot_split
# Out:
#                            song       artist_1      artist_2   artist_3
# 0                       Flowers    Miley Cyrus          None       None
# 1                     Kill Bill            SZA          None       None
# 2                    Last Night  Morgan Wallen          None       None
# 3                        Unholy      Sam Smith    Kim Petras       None
# 4                      Creepin'   Metro Boomin    The Weeknd  21 Savage
# ..                          ...            ...           ...        ...
# 95                   Yandel 150         Yandel          Feid       None
# 96               Heart To Heart    Mac DeMarco          None       None
# 97          Next Thing You Know   Jordan Davis          None       None
# 98  Never Gonna Not Dance Again           P!nk          None       None
# 99                    Open Arms            SZA  Travis Scott       None
#
# [100 rows x 4 columns]

# %%
# Define a function to find the ID of a song by song and artist
def find_track_id(song, artist):
    results = sp.search(q = song, limit = 30, market="GB")
    for i in range(len(results['tracks']['items'])):
        if results['tracks']['items'][i]['artists'][0]['name'] == artist:
            track_id = results["tracks"]["items"][i]["id"]
    return track_id

# %%
# Define a function to find the first ID of a song only by song
def find_track_id_first(song):
    results = sp.search(q = song, limit = 1, market="GB")
    track_id = results["tracks"]["items"][0]["id"]
    return track_id

# %%
# Define a function to find the name of a song via track ID
def find_track_name(track_id):
    track = sp.track(track_id)
    track_name = track['name']
    return track_name

# %%
sp.search(q = "Fin de Semana", limit = 10, market="GB")
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Fin+de+Semana&type=track&market=GB&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3l9G1G9MxH6DaRhwLklaf5'},
#        'href': 'https://api.spotify.com/v1/artists/3l9G1G9MxH6DaRhwLklaf5',
#        'id': '3l9G1G9MxH6DaRhwLklaf5',
#        'name': 'Oscar Maydon',
#        'type': 'artist',
#        'uri': 'spotify:artist:3l9G1G9MxH6DaRhwLklaf5'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Gi6gjaWy3DxyilpF1a8Is'},
#        'href': 'https://api.spotify.com/v1/artists/7Gi6gjaWy3DxyilpF1a8Is',
#        'id': '7Gi6gjaWy3DxyilpF1a8Is',
#        'name': 'Junior H',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Gi6gjaWy3DxyilpF1a8Is'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/366AAoKCXunrJSqKqZuafy'},
#      'href': 'https://api.spotify.com/v1/albums/366AAoKCXunrJSqKqZuafy',
#      'id': '366AAoKCXunrJSqKqZuafy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739b7e1ea3815a172019bc5e56',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029b7e1ea3815a172019bc5e56',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519b7e1ea3815a172019bc5e56',
#        'width': 64}],
#      'name': 'Fin de Semana',
#      'release_date': '2023-01-13',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:366AAoKCXunrJSqKqZuafy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3l9G1G9MxH6DaRhwLklaf5'},
#       'href': 'https://api.spotify.com/v1/artists/3l9G1G9MxH6DaRhwLklaf5',
#       'id': '3l9G1G9MxH6DaRhwLklaf5',
#       'name': 'Oscar Maydon',
#       'type': 'artist',
#       'uri': 'spotify:artist:3l9G1G9MxH6DaRhwLklaf5'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Gi6gjaWy3DxyilpF1a8Is'},
#       'href': 'https://api.spotify.com/v1/artists/7Gi6gjaWy3DxyilpF1a8Is',
#       'id': '7Gi6gjaWy3DxyilpF1a8Is',
#       'name': 'Junior H',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Gi6gjaWy3DxyilpF1a8Is'}],
#     'disc_number': 1,
#     'duration_ms': 224920,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZ9QQ2300040'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6TBzRwnX2oYd8aOrOuyK1p'},
#     'href': 'https://api.spotify.com/v1/tracks/6TBzRwnX2oYd8aOrOuyK1p',
#     'id': '6TBzRwnX2oYd8aOrOuyK1p',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Fin de Semana',
#     'popularity': 85,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3955225c26830ce9ae13c940ccf2a606baf51c3f?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6TBzRwnX2oYd8aOrOuyK1p'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1xAY4oDpdxkQWODMSvHMZJ'},
#      'href': 'https://api.spotify.com/v1/albums/1xAY4oDpdxkQWODMSvHMZJ',
#      'id': '1xAY4oDpdxkQWODMSvHMZJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d045248d8c14fb37b3f8cfd7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d045248d8c14fb37b3f8cfd7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d045248d8c14fb37b3f8cfd7',
#        'width': 64}],
#      'name': 'Pasando el rato con mis hermanos',
#      'release_date': '2023-02-11',
#      'release_date_precision': 'day',
#      'total_tracks': 26,
#      'type': 'album',
#      'uri': 'spotify:album:1xAY4oDpdxkQWODMSvHMZJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vyhD5VmyZ7KMfW5gqLgo5'},
#       'href': 'https://api.spotify.com/v1/artists/1vyhD5VmyZ7KMfW5gqLgo5',
#       'id': '1vyhD5VmyZ7KMfW5gqLgo5',
#       'name': 'J Balvin',
#       'type': 'artist',
#       'uri': 'spotify:artist:1vyhD5VmyZ7KMfW5gqLgo5'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'duration_ms': 243560,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71702120'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0jdz4rzDO2fs5bXY2381jg'},
#     'href': 'https://api.spotify.com/v1/tracks/0jdz4rzDO2fs5bXY2381jg',
#     'id': '0jdz4rzDO2fs5bXY2381jg',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Si Tu Novio Te Deja Sola',
#     'popularity': 3,
#     'preview_url': 'https://p.scdn.co/mp3-preview/546d4c3782c4f830dc3d62c599232ecc79827c5d?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:0jdz4rzDO2fs5bXY2381jg'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yNxJZdVBh5mWnGLiBtB0H'},
#        'href': 'https://api.spotify.com/v1/artists/4yNxJZdVBh5mWnGLiBtB0H',
#        'id': '4yNxJZdVBh5mWnGLiBtB0H',
#        'name': 'El Aparato Negro',
#        'type': 'artist',
#        'uri': 'spotify:artist:4yNxJZdVBh5mWnGLiBtB0H'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4YawnWcdJqMIz4YW8kZUU7'},
#      'href': 'https://api.spotify.com/v1/albums/4YawnWcdJqMIz4YW8kZUU7',
#      'id': '4YawnWcdJqMIz4YW8kZUU7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731717198b070809cf301bf5bb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021717198b070809cf301bf5bb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511717198b070809cf301bf5bb',
#        'width': 64}],
#      'name': 'fin de semana',
#      'release_date': '2022-07-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4YawnWcdJqMIz4YW8kZUU7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yNxJZdVBh5mWnGLiBtB0H'},
#       'href': 'https://api.spotify.com/v1/artists/4yNxJZdVBh5mWnGLiBtB0H',
#       'id': '4yNxJZdVBh5mWnGLiBtB0H',
#       'name': 'El Aparato Negro',
#       'type': 'artist',
#       'uri': 'spotify:artist:4yNxJZdVBh5mWnGLiBtB0H'}],
#     'disc_number': 1,
#     'duration_ms': 191703,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZMEN2234013'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5i3QBb36OnBXrlpcjRPE6A'},
#     'href': 'https://api.spotify.com/v1/tracks/5i3QBb36OnBXrlpcjRPE6A',
#     'id': '5i3QBb36OnBXrlpcjRPE6A',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'fin de semana',
#     'popularity': 23,
#     'preview_url': 'https://p.scdn.co/mp3-preview/90ec94d063ce2db34c9788e894b6fc6b17c94b50?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5i3QBb36OnBXrlpcjRPE6A'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1xoViNBVbFsLocZAvcQm1N'},
#      'href': 'https://api.spotify.com/v1/albums/1xoViNBVbFsLocZAvcQm1N',
#      'id': '1xoViNBVbFsLocZAvcQm1N',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273596ee817303517dbf19dd9ee',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02596ee817303517dbf19dd9ee',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851596ee817303517dbf19dd9ee',
#        'width': 64}],
#      'name': 'Pachanga De Alcurnia Vol. 3',
#      'release_date': '2023-02-17',
#      'release_date_precision': 'day',
#      'total_tracks': 27,
#      'type': 'album',
#      'uri': 'spotify:album:1xoViNBVbFsLocZAvcQm1N'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/07YUOmWljBTXwIseAUd9TW'},
#       'href': 'https://api.spotify.com/v1/artists/07YUOmWljBTXwIseAUd9TW',
#       'id': '07YUOmWljBTXwIseAUd9TW',
#       'name': 'Sebastian Yatra',
#       'type': 'artist',
#       'uri': 'spotify:artist:07YUOmWljBTXwIseAUd9TW'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#       'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#       'id': '4VMYDCV2IEDYJArk749S6m',
#       'name': 'Daddy Yankee',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1GDbiv3spRmZ1XdM1jQbT7'},
#       'href': 'https://api.spotify.com/v1/artists/1GDbiv3spRmZ1XdM1jQbT7',
#       'id': '1GDbiv3spRmZ1XdM1jQbT7',
#       'name': 'Natti Natasha',
#       'type': 'artist',
#       'uri': 'spotify:artist:1GDbiv3spRmZ1XdM1jQbT7'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#       'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#       'id': '7gOdHgIoIKoe4i9Tta6qdD',
#       'name': 'Jonas Brothers',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#     'disc_number': 1,
#     'duration_ms': 202866,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71910638'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3WkFwFFVGH3grAeHDG6uXt'},
#     'href': 'https://api.spotify.com/v1/tracks/3WkFwFFVGH3grAeHDG6uXt',
#     'id': '3WkFwFFVGH3grAeHDG6uXt',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Runaway',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3569e794ec0db5889d3451e493fdefdda1a3f088?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 27,
#     'type': 'track',
#     'uri': 'spotify:track:3WkFwFFVGH3grAeHDG6uXt'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/68YeXpLt3jB7JHQS5ZjMGo'},
#        'href': 'https://api.spotify.com/v1/artists/68YeXpLt3jB7JHQS5ZjMGo',
#        'id': '68YeXpLt3jB7JHQS5ZjMGo',
#        'name': 'Teto',
#        'type': 'artist',
#        'uri': 'spotify:artist:68YeXpLt3jB7JHQS5ZjMGo'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/02q2gOT5jYZN9fXLPFxy9S'},
#      'href': 'https://api.spotify.com/v1/albums/02q2gOT5jYZN9fXLPFxy9S',
#      'id': '02q2gOT5jYZN9fXLPFxy9S',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273acb087ed5213035b71ef7a80',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02acb087ed5213035b71ef7a80',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851acb087ed5213035b71ef7a80',
#        'width': 64}],
#      'name': 'Fim de Semana no Rio',
#      'release_date': '2022-03-30',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:02q2gOT5jYZN9fXLPFxy9S'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/68YeXpLt3jB7JHQS5ZjMGo'},
#       'href': 'https://api.spotify.com/v1/artists/68YeXpLt3jB7JHQS5ZjMGo',
#       'id': '68YeXpLt3jB7JHQS5ZjMGo',
#       'name': 'Teto',
#       'type': 'artist',
#       'uri': 'spotify:artist:68YeXpLt3jB7JHQS5ZjMGo'}],
#     'disc_number': 1,
#     'duration_ms': 165882,
#     'explicit': True,
#     'external_ids': {'isrc': 'BXW922200001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7afaZ37wJJL6880z1NRgJS'},
#     'href': 'https://api.spotify.com/v1/tracks/7afaZ37wJJL6880z1NRgJS',
#     'id': '7afaZ37wJJL6880z1NRgJS',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Fim de Semana no Rio',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6ecdd95fa8d0008f65c5f3b572f16b8139642340?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7afaZ37wJJL6880z1NRgJS'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0HacMDf3ckGNlZxJRtQk55'},
#        'href': 'https://api.spotify.com/v1/artists/0HacMDf3ckGNlZxJRtQk55',
#        'id': '0HacMDf3ckGNlZxJRtQk55',
#        'name': 'Dío Cabrera',
#        'type': 'artist',
#        'uri': 'spotify:artist:0HacMDf3ckGNlZxJRtQk55'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0gcjTxTgeO4lLQLjd8HwuG'},
#        'href': 'https://api.spotify.com/v1/artists/0gcjTxTgeO4lLQLjd8HwuG',
#        'id': '0gcjTxTgeO4lLQLjd8HwuG',
#        'name': '24kFerragamo',
#        'type': 'artist',
#        'uri': 'spotify:artist:0gcjTxTgeO4lLQLjd8HwuG'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2kdNCLQdxn9i8bjK0s5zSE'},
#      'href': 'https://api.spotify.com/v1/albums/2kdNCLQdxn9i8bjK0s5zSE',
#      'id': '2kdNCLQdxn9i8bjK0s5zSE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273552d0ba3dc4d8ec2ea3d19a4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02552d0ba3dc4d8ec2ea3d19a4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851552d0ba3dc4d8ec2ea3d19a4',
#        'width': 64}],
#      'name': 'Fin de Semana',
#      'release_date': '2019-09-17',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2kdNCLQdxn9i8bjK0s5zSE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0HacMDf3ckGNlZxJRtQk55'},
#       'href': 'https://api.spotify.com/v1/artists/0HacMDf3ckGNlZxJRtQk55',
#       'id': '0HacMDf3ckGNlZxJRtQk55',
#       'name': 'Dío Cabrera',
#       'type': 'artist',
#       'uri': 'spotify:artist:0HacMDf3ckGNlZxJRtQk55'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0gcjTxTgeO4lLQLjd8HwuG'},
#       'href': 'https://api.spotify.com/v1/artists/0gcjTxTgeO4lLQLjd8HwuG',
#       'id': '0gcjTxTgeO4lLQLjd8HwuG',
#       'name': '24kFerragamo',
#       'type': 'artist',
#       'uri': 'spotify:artist:0gcjTxTgeO4lLQLjd8HwuG'}],
#     'disc_number': 1,
#     'duration_ms': 194419,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZHZ31976907'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/54tW08NPBDt2QGF6kTQOPB'},
#     'href': 'https://api.spotify.com/v1/tracks/54tW08NPBDt2QGF6kTQOPB',
#     'id': '54tW08NPBDt2QGF6kTQOPB',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Fin de Semana',
#     'popularity': 22,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8d146e3629aadb0fa02423ad1a4896d0447a89e1?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:54tW08NPBDt2QGF6kTQOPB'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3ssHRUw9OPe24Gz953Glc1'},
#      'href': 'https://api.spotify.com/v1/albums/3ssHRUw9OPe24Gz953Glc1',
#      'id': '3ssHRUw9OPe24Gz953Glc1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bb5ad5ad5785728b02ab29ed',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bb5ad5ad5785728b02ab29ed',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bb5ad5ad5785728b02ab29ed',
#        'width': 64}],
#      'name': 'Disfruta La Party Vol. 5',
#      'release_date': '2023-02-15',
#      'release_date_precision': 'day',
#      'total_tracks': 27,
#      'type': 'album',
#      'uri': 'spotify:album:3ssHRUw9OPe24Gz953Glc1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/07YUOmWljBTXwIseAUd9TW'},
#       'href': 'https://api.spotify.com/v1/artists/07YUOmWljBTXwIseAUd9TW',
#       'id': '07YUOmWljBTXwIseAUd9TW',
#       'name': 'Sebastian Yatra',
#       'type': 'artist',
#       'uri': 'spotify:artist:07YUOmWljBTXwIseAUd9TW'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#       'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#       'id': '4VMYDCV2IEDYJArk749S6m',
#       'name': 'Daddy Yankee',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1GDbiv3spRmZ1XdM1jQbT7'},
#       'href': 'https://api.spotify.com/v1/artists/1GDbiv3spRmZ1XdM1jQbT7',
#       'id': '1GDbiv3spRmZ1XdM1jQbT7',
#       'name': 'Natti Natasha',
#       'type': 'artist',
#       'uri': 'spotify:artist:1GDbiv3spRmZ1XdM1jQbT7'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#       'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#       'id': '7gOdHgIoIKoe4i9Tta6qdD',
#       'name': 'Jonas Brothers',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#     'disc_number': 1,
#     'duration_ms': 202866,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71910638'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2SvR4tL2BdqKPlgyc8s1Yj'},
#     'href': 'https://api.spotify.com/v1/tracks/2SvR4tL2BdqKPlgyc8s1Yj',
#     'id': '2SvR4tL2BdqKPlgyc8s1Yj',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Runaway',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3569e794ec0db5889d3451e493fdefdda1a3f088?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 26,
#     'type': 'track',
#     'uri': 'spotify:track:2SvR4tL2BdqKPlgyc8s1Yj'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4VY4IXXRTbEZeJwV9gu6ki'},
#        'href': 'https://api.spotify.com/v1/artists/4VY4IXXRTbEZeJwV9gu6ki',
#        'id': '4VY4IXXRTbEZeJwV9gu6ki',
#        'name': 'Traffic Gvng',
#        'type': 'artist',
#        'uri': 'spotify:artist:4VY4IXXRTbEZeJwV9gu6ki'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4StQh17zinsbJ4r5ekmPj7'},
#        'href': 'https://api.spotify.com/v1/artists/4StQh17zinsbJ4r5ekmPj7',
#        'id': '4StQh17zinsbJ4r5ekmPj7',
#        'name': 'Coqeéin Montana',
#        'type': 'artist',
#        'uri': 'spotify:artist:4StQh17zinsbJ4r5ekmPj7'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5YOTEwM87shWIWczz4NPgE'},
#      'href': 'https://api.spotify.com/v1/albums/5YOTEwM87shWIWczz4NPgE',
#      'id': '5YOTEwM87shWIWczz4NPgE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737937c7bb5f7465d7ec7db3e2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027937c7bb5f7465d7ec7db3e2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517937c7bb5f7465d7ec7db3e2',
#        'width': 64}],
#      'name': 'Fin De Semana',
#      'release_date': '2022-04-05',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5YOTEwM87shWIWczz4NPgE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4VY4IXXRTbEZeJwV9gu6ki'},
#       'href': 'https://api.spotify.com/v1/artists/4VY4IXXRTbEZeJwV9gu6ki',
#       'id': '4VY4IXXRTbEZeJwV9gu6ki',
#       'name': 'Traffic Gvng',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VY4IXXRTbEZeJwV9gu6ki'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4StQh17zinsbJ4r5ekmPj7'},
#       'href': 'https://api.spotify.com/v1/artists/4StQh17zinsbJ4r5ekmPj7',
#       'id': '4StQh17zinsbJ4r5ekmPj7',
#       'name': 'Coqeéin Montana',
#       'type': 'artist',
#       'uri': 'spotify:artist:4StQh17zinsbJ4r5ekmPj7'}],
#     'disc_number': 1,
#     'duration_ms': 158608,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZGLS2296771'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/31ictrSv966BFtCwuSR5Qn'},
#     'href': 'https://api.spotify.com/v1/tracks/31ictrSv966BFtCwuSR5Qn',
#     'id': '31ictrSv966BFtCwuSR5Qn',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Fin De Semana',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/15ca31c73b7e0806425f78489ad86b3a8ebcd9c1?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:31ictrSv966BFtCwuSR5Qn'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6smoHVfetZcWkjKGcdPLdp'},
#      'href': 'https://api.spotify.com/v1/albums/6smoHVfetZcWkjKGcdPLdp',
#      'id': '6smoHVfetZcWkjKGcdPLdp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a315f3894a31d6af133b5835',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a315f3894a31d6af133b5835',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a315f3894a31d6af133b5835',
#        'width': 64}],
#      'name': 'Fiesta !',
#      'release_date': '2023-02-03',
#      'release_date_precision': 'day',
#      'total_tracks': 45,
#      'type': 'album',
#      'uri': 'spotify:album:6smoHVfetZcWkjKGcdPLdp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/14zUHaJZo1mnYtn6IBRaRP'},
#       'href': 'https://api.spotify.com/v1/artists/14zUHaJZo1mnYtn6IBRaRP',
#       'id': '14zUHaJZo1mnYtn6IBRaRP',
#       'name': 'Justin Quiles',
#       'type': 'artist',
#       'uri': 'spotify:artist:14zUHaJZo1mnYtn6IBRaRP'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VVEpEhC8NcR7AqNEds42U'},
#       'href': 'https://api.spotify.com/v1/artists/4VVEpEhC8NcR7AqNEds42U',
#       'id': '4VVEpEhC8NcR7AqNEds42U',
#       'name': 'Chimbala',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VVEpEhC8NcR7AqNEds42U'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/21451j1KhjAiaYKflxBjr1'},
#       'href': 'https://api.spotify.com/v1/artists/21451j1KhjAiaYKflxBjr1',
#       'id': '21451j1KhjAiaYKflxBjr1',
#       'name': 'Zion & Lennox',
#       'type': 'artist',
#       'uri': 'spotify:artist:21451j1KhjAiaYKflxBjr1'}],
#     'disc_number': 1,
#     'duration_ms': 231603,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWL12100223'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6OQ1KBVubSWkNBwnGbf2sy'},
#     'href': 'https://api.spotify.com/v1/tracks/6OQ1KBVubSWkNBwnGbf2sy',
#     'id': '6OQ1KBVubSWkNBwnGbf2sy',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Loco',
#     'popularity': 2,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fa268bc57c848ca219997e86bb5f64490476a1dc?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:6OQ1KBVubSWkNBwnGbf2sy'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6NHwemaQbXgRfqEE4Hvm4a'},
#        'href': 'https://api.spotify.com/v1/artists/6NHwemaQbXgRfqEE4Hvm4a',
#        'id': '6NHwemaQbXgRfqEE4Hvm4a',
#        'name': 'Abi Hinojosa',
#        'type': 'artist',
#        'uri': 'spotify:artist:6NHwemaQbXgRfqEE4Hvm4a'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0pCajKRgF97BBGPB0kXhOH'},
#      'href': 'https://api.spotify.com/v1/albums/0pCajKRgF97BBGPB0kXhOH',
#      'id': '0pCajKRgF97BBGPB0kXhOH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738ed545de087d9089378587db',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028ed545de087d9089378587db',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518ed545de087d9089378587db',
#        'width': 64}],
#      'name': 'Mi Propio Estilo',
#      'release_date': '2021-07-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:0pCajKRgF97BBGPB0kXhOH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6NHwemaQbXgRfqEE4Hvm4a'},
#       'href': 'https://api.spotify.com/v1/artists/6NHwemaQbXgRfqEE4Hvm4a',
#       'id': '6NHwemaQbXgRfqEE4Hvm4a',
#       'name': 'Abi Hinojosa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6NHwemaQbXgRfqEE4Hvm4a'}],
#     'disc_number': 1,
#     'duration_ms': 190702,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZK6P2164955'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/31iWyeakfFc0ZZ2bjQ0I2u'},
#     'href': 'https://api.spotify.com/v1/tracks/31iWyeakfFc0ZZ2bjQ0I2u',
#     'id': '31iWyeakfFc0ZZ2bjQ0I2u',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Fin De Semana',
#     'popularity': 20,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3062d54bc1226db763d28b50d18ee067fc8cfa08?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:31iWyeakfFc0ZZ2bjQ0I2u'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=Fin+de+Semana&type=track&market=GB&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 1000}}

# %%
# Define a function to find the artist of a song via track ID
def find_track_artist(track_id):
    track = sp.track(track_id)
    artist_name = track['artists'][0]['name']
    return artist_name

# %%
# for i in range(len(results['tracks']['items'])):
#     if results['tracks']['items'][i]['artists'][0]['name'] == 'Ed Sheeran':
#         track_id = results["tracks"]["items"][i]["id"]

# %%
# Define a function to save the sound features of a song to a dataframe
def get_sound_features(track_id):
    features = sp.audio_features(tracks=[track_id])
    feature_df = pd.DataFrame(features)
    feature_df = feature_df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","duration_ms"]]
    return feature_df

# %%
# Define a function to predict the cluster label of a song
def cluster_label(features_df):
    scaler = StandardScaler()
    scaler.fit(X_num)
    features_scaled = scaler.transform(features_df)
    features_scaled_df = pd.DataFrame(features_scaled, columns = features_df.columns)
    cluster_num = kmeans.predict(features_scaled_df)[0]
    return cluster_num

# %%
# Define a function to get the ID of the song ramdonly chosen from the specific cluster
def rec_sample_id(cluster_num):
    rec_df = X_clustered[X_clustered['cluster'] == cluster_num]
    rec_id = rec_df.sample()['id'].values[0]
    return rec_id

# %%
# Define a function to list out the other possible artists for the input song 
def other_artists(song, selected_artist):
    results = sp.search(q = song, limit = 30, market="GB")
    artist_list = []
    for i in range(len(results['tracks']['items'])):
        artist_list.append(results['tracks']['items'][i]['artists'][0]['name'])
    artist_list = list(set(artist_list)) # remove duplicates
    artist_list.remove(selected_artist)
    return artist_list

# %%
# Define a function to print a list with an ordinal number before each artist

def list_with_number(artist_list):    
    artist_list_string = ''
    for i, artist in enumerate(artist_list):
        artist_list_string += f"{i+1}. {artist}, "

    artist_list_string = artist_list_string[:-2] # Remove the final comma and space
    return artist_list_string

# %%
def track_artist_pair(song):
    results = sp.search(q=song, limit=30, market="GB")

    track_artist = []
    for i in range(len(results['tracks']['items'])):
        artist = results['tracks']['items'][i]['artists'][0]['name']
        track = results['tracks']['items'][i]['name']
        # pair tracks and artists with dash
        pair = f"{track} - {artist}"
        # make sure there is no dupilicates
        if pair not in track_artist:
            track_artist.append(pair)
    # add order number for each pair
    track_artist_numbered = [f"{i+1}. {pair}" for i, pair in enumerate(track_artist)]

    return track_artist_numbered

# %%
# Define a function to search a song name Spotify and list song names and artist names as pairs
def track_artist_pair(song):
    results = sp.search(q = song, limit = 10, market = "GB")

    artist_list = []
    track_list = []

    for i in range(len(results['tracks']['items'])):
        artist = results['tracks']['items'][i]['artists'][0]['name']
        track = results['tracks']['items'][i]['name']
        
        # check if track artist pair has already been added
        if f"{track} - {artist}" not in track_list:
            artist_list.append(artist)
            track_list.append(track)

    # create list of track artist pairs with order number
    track_artist = [f"{i+1}. {x} - {y}" for i, (x, y) in enumerate(zip(track_list, artist_list))]

    return track_artist, artist_list, track_list

# %%
track_artist_1, artist_list_1, track_list_1 = track_artist_pair("Lemon Tree")

# %%
artist_list = ['Mundo Suave', 'Ghost and Pals', 'The Beautiful South', 'Mason', 'Sam Smith', 'Mareux', 'Jonas Blue', 'Lou Reed', 'beabadoobee', 'SlowFez', 'One Direction', 'White Noise Baby Sleep', 'Cousin Stizz', 'Powell Sullivan']
print(f'No problem! Is the song performed by one of the following artists: {list_with_number(artist_list)}? (Y/N)')
# Out:
# No problem! Is the song performed by one of the following artists: 1. Mundo Suave, 2. Ghost and Pals, 3. The Beautiful South, 4. Mason, 5. Sam Smith, 6. Mareux, 7. Jonas Blue, 8. Lou Reed, 9. beabadoobee, 10. SlowFez, 11. One Direction, 12. White Noise Baby Sleep, 13. Cousin Stizz, 14. Powell Sullivan? (Y/N)

# %%
artist_list
# Out:
# ['Mundo Suave',
#  'Ghost and Pals',
#  'The Beautiful South',
#  'Mason',
#  'Sam Smith',
#  'Mareux',
#  'Jonas Blue',
#  'Lou Reed',
#  'beabadoobee',
#  'SlowFez',
#  'One Direction',
#  'White Noise Baby Sleep',
#  'Cousin Stizz',
#  'Powell Sullivan']

# %%
# def GrooveGenie():
#     while True:
#         input_song = input('Please enter a hot song: ')
#         match_ratios = [fuzz.token_set_ratio(input_song.lower(), s.lower()) for s in hot.song] # Generate a list of matching scores
#         max_ratio = max(match_ratios) # Get the highest matching score
#         if max_ratio >= 70:
#             input_song = hot.song[match_ratios.index(max_ratio)] # Correct the input by the song which matches the input best
#             check_singer = hot.loc[hot.song.str.lower() == input_song.lower(), 'artist'][0]
#             comfirm = input(f'Do you mean "{input_song}" performed by "{check_singer}"? (Y/N) ')
#             if comfirm.lower() == 'y':
#                 print(f'Got it! Playing "{input_song}"!')
#                 play_song(find_track_id(input_song)) # Play the song
#                 break
#             else:
#                 rec_hot = random.sample(hot.song.tolist(), k=5)
#                 print(f'Sorry, this is not a hot song. Would you like to try one of these hot songs? {rec_hot}')
#         else:
#             rec_hot = random.sample(hot.song.tolist(), k=5)
#             print(f'Sorry, this is not a hot song. Would you like to try one of these hot songs? {rec_hot}')

# %%
# # Update find_track_id() (two arguemnets)

# def GrooveGenie():
#     while True:
#         input_song = input('Please enter a hot song: ')
#         match_ratios = [fuzz.token_set_ratio(input_song.lower(), s.lower()) for s in hot.song] # Generate a list of matching scores
#         max_ratio = max(match_ratios) # Get the highest matching score
#         if max_ratio >= 70:
#             input_song = hot.song[match_ratios.index(max_ratio)] # Correct the input by the song which matches the input best
#             check_singer = hot.loc[hot.song.str.lower() == input_song.lower(), 'artist'][0]
#             comfirm = input(f'Do you mean "{input_song}" performed by "{check_singer}"? (Y/N) ')
#             if comfirm.lower() == 'y':
#                 print(f'Got it! Playing "{input_song}" performed by "{check_singer}"!')
#                 display(play_song(find_track_id(input_song, check_singer))) # Play the song
#                 break
#             else:
#                 rec_hot = random.sample(hot.song.tolist(), k=1)
#                 print(f'Sorry, this is not a hot song. Would you like to try one of these hot songs? {rec_hot}')
#         else:
#             rec_hot = random.sample(hot.song.tolist(), k=5)
#             print(f'Sorry, this is not a hot song. Would you like to try one of these hot songs? {rec_hot}')

# %%
# # Recommend another hot song and play it

# def GrooveGenie():
#     while True:
#         input_song = input('Please enter a hot song: ')
#         match_ratios = [fuzz.token_set_ratio(input_song.lower(), s.lower()) for s in hot.song] # Generate a list of matching scores
#         max_ratio = max(match_ratios) # Get the highest matching score
#         if max_ratio >= 70:
#             input_song = hot.song[match_ratios.index(max_ratio)] # Correct the input by the song which matches the input best
#             check_singer = hot.loc[hot.song.str.lower() == input_song.lower(), 'artist'][0]
#             comfirm = input(f'Do you mean "{input_song}" performed by "{check_singer}"? (Y/N) ')
            
#             if comfirm.lower() == 'y':
#                 print(f'Got it! Playing "{input_song}" performed by "{check_singer}"!')
#                 display(play_song(find_track_id(input_song, check_singer))) # Play the song
                
#                 # Recommend another hot song and play it
#                 rec_hot = random.sample(hot.song.tolist(), k=1)[0]
#                 rec_hot_request = input(f'Would you like to try another hot song: "{rec_hot}"? (Y/N)')
#                 if rec_hot_request.lower() == 'y':
#                     rec_hot_singer = hot_split.loc[hot_split.song.str.lower() == rec_hot.lower(), 'artist_1'].iloc[0]
#                     print(f'Wonderful! Playing "{rec_hot}" performed by "{rec_hot_singer}"!')
#                     display(play_song(find_track_id(rec_hot, rec_hot_singer)))
#                     print(f'Thank you for using GrooveGenie!')
#                     break
#                 else:
#                     print(f'Thank you for using GrooveGenie!')
#                     break
                            
#             else:
#                 rec_hot = random.sample(hot.song.tolist(), k=1)
#                 print(f'Sorry, this is not a hot song. Would you like to try one of these hot songs? {rec_hot}')
#         else:
#             rec_hot = random.sample(hot.song.tolist(), k=5)
#             print(f'Sorry, this is not a hot song. Would you like to try one of these hot songs? {rec_hot}')

# %%
# # Feature: Recommend another song depending on the audio features      
# # Sub-Feature: Let user to choose a possible artist and play it accordingly

# def GrooveGenie():
#     while True:
#         input_song = input('Please enter a song: ')
#         match_ratios = [fuzz.token_set_ratio(input_song.lower(), s.lower()) for s in hot.song] # Generate a list of matching scores
#         max_ratio = max(match_ratios) # Get the highest matching score
#         if max_ratio >= 70:
#             input_hot_song = hot.song[match_ratios.index(max_ratio)] # Correct the input by the song which matches the input best
#             check_singer = hot.loc[hot.song.str.lower() == input_hot_song.lower(), 'artist'][0]
#             comfirm_hot_artist = input(f'Do you mean "{input_hot_song}" performed by "{check_singer}"? (Y/N) ')
            
#             if comfirm_hot_artist.lower() == 'y':
#                 print(f'Got it! Playing "{input_hot_song}" performed by "{check_singer}"!')
#                 display(play_song(find_track_id(input_hot_song, check_singer))) # Play the song
                
#                 # Recommend another hot song and play it
#                 rec_hot = random.sample(hot.song.tolist(), k=1)[0]
#                 rec_hot_request = input(f'Would you like to try another hot song: "{rec_hot}"? (Y/N)')
#                 if rec_hot_request.lower() == 'y':
#                     rec_hot_singer = hot_split.loc[hot_split.song.str.lower() == rec_hot.lower(), 'artist_1'].iloc[0]
#                     print(f'Wonderful! Playing "{rec_hot}" performed by "{rec_hot_singer}"!')
#                     display(play_song(find_track_id(rec_hot, rec_hot_singer)))
#                     print(f'Thank you for using GrooveGenie!')
#                     break
#                 elif rec_hot_request.lower() == 'n':
#                     print(f'No problem! Thank you for using GrooveGenie!')
#                     break
#                 else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
                    
#             # Recommend another song depending on the audio features        
#             elif comfirm_hot_artist.lower() == 'n':
#                 # Let user to choose a possible artist and play it accordingly
#                 other_artists_list = other_artists(input_song, check_singer)
#                 print(f'No problem! Is the song performed by one of the following artists: {list_with_number(other_artists_list)}?')
#                 choose_artist = input(f'If the artist is listed, please input the number to choose; otherwise please input "N".')
#                 if choose_artist.lower() == 'n':
#                     print(f'I am sorry, the song you entered might not be found.')
#                     continue
#                 elif choose_artist.isdigit() and int(choose_artist) in range(1, len(other_artists_list)):
#                     chosen_artist = other_artists_list[int(choose_artist) - 1]
#                     print(f'Got it! Playing "{find_track_name(input_song, chosen_artist)}" performed by "{chosen_artist}".')
#                     display(play_song(find_track_id(input_song, chosen_artist)))
                    
#                 else: 
#                     print(f'Please enter a number between 1 and {len(other_artists_list)} or letter "N" (for "No").')
#                     # Loose end!!! This won't send user back to 'choose_artist' input
                
#             else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
#         else:
#             rec_hot = random.sample(hot.song.tolist(), k=5)
#             print(f'Sorry, this is not a hot song. Would you like to try one of these hot songs? {rec_hot}')

# %%
# # Feature: Recommend another song depending on the audio features of the song whose name is same with one in the hot list     
# # Sub-Feature: Ask user if want to listen another song

# def GrooveGenie():
#     while True:
#         input_song = input('Please enter a song: ')
#         match_ratios = [fuzz.token_set_ratio(input_song.lower(), s.lower()) for s in hot.song] # Generate a list of matching scores
#         max_ratio = max(match_ratios) # Get the highest matching score
#         if max_ratio >= 70:
#             input_hot_song = hot.song[match_ratios.index(max_ratio)] # Correct the input by the song which matches the input best
#             check_singer = hot.loc[hot.song.str.lower() == input_hot_song.lower(), 'artist'][0]
#             comfirm_hot_artist = input(f'Do you mean "{input_hot_song}" performed by "{check_singer}"? (Y/N) ')
            
#             if comfirm_hot_artist.lower() == 'y':
#                 print(f'Got it! Playing "{input_hot_song}" performed by "{check_singer}"!')
#                 display(play_song(find_track_id(input_hot_song, check_singer))) # Play the song
                
#                 # Recommend another hot song and play it
#                 rec_hot = random.sample(hot.song.tolist(), k=1)[0]
#                 rec_hot_request = input(f'Would you like to try another hot song: "{rec_hot}"? (Y/N)')
#                 if rec_hot_request.lower() == 'y':
#                     rec_hot_singer = hot_split.loc[hot_split.song.str.lower() == rec_hot.lower(), 'artist_1'].iloc[0]
#                     print(f'Wonderful! Playing "{rec_hot}" performed by "{rec_hot_singer}"!')
#                     display(play_song(find_track_id(rec_hot, rec_hot_singer)))
#                     print(f'Thank you for using GrooveGenie!')
#                     break
#                 elif rec_hot_request.lower() == 'n':
#                     print(f'No problem! Thank you for using GrooveGenie!')
#                     break
#                 else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
                    
#             # Recommend another song depending on the audio features        
#             elif comfirm_hot_artist.lower() == 'n':
#                 # Let user to choose a possible artist and play it accordingly
#                 other_artists_list = other_artists(input_song, check_singer)
#                 print(f'No problem! Is the song performed by one of the following artists: {list_with_number(other_artists_list)}?')
#                 choose_artist = input(f'If the artist is listed, please input the number to choose; otherwise please input "N".')
#                 if choose_artist.lower() == 'n':
#                     print(f'I am sorry, the song you entered might not be found.')
#                     continue
#                 elif choose_artist.isdigit() and int(choose_artist) in range(1, len(other_artists_list)):
#                     chosen_artist = other_artists_list[int(choose_artist) - 1]
#                     chosen_track_id = find_track_id(input_song, chosen_artist)
#                     chosen_track_name = find_track_name(chosen_track_id)
#                     print(f'Got it! Playing "{chosen_track_name}" performed by "{chosen_artist}".')
#                     display(play_song(chosen_track_id))
                    
#                     # Ask user if want to listen another song
#                     rec_other_request = input(f'Would you like to try another song like this one: "{chosen_track_name}"? (Y/N)')
                    
#                     if rec_other_request.lower() == 'y':
#                         chosen_track_features_df = get_sound_features(chosen_track_id)
#                         chosen_track_label = cluster_label(chosen_track_features_df)
#                         rec_other_id = rec_sample_id(chosen_track_label)
#                         rec_other_name = find_track_name(rec_other_id)
#                         rec_other_artist = find_track_artist(rec_other_id)

#                         print(f'Wonderful! Playing "{rec_other_name}" performed by "{rec_other_artist}"!')
#                         display(play_song(rec_other_id))
#                         print(f'Thank you for using GrooveGenie!')
#                         break
#                     elif rec_hot_request.lower() == 'n':
#                         print(f'No problem! Thank you for using GrooveGenie!')
#                         break
#                     else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')

#                 else: 
#                     print(f'Please enter a number between 1 and {len(other_artists_list)} or letter "N" (for "No").')
#                     # Loose end!!! This won't send user back to 'choose_artist' input
                
#             else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
#         else:
#             rec_hot = random.sample(hot.song.tolist(), k=5)
#             print(f'Sorry, this is not a hot song. Would you like to try one of these hot songs? {rec_hot}')

# %%
# # Feature: Play the input song out of the hot list     

# def GrooveGenie():
#     while True:
#         input_song = input('Please enter a song: ')
#         match_ratios = [fuzz.token_set_ratio(input_song.lower(), s.lower()) for s in hot.song] # Generate a list of matching scores
#         max_ratio = max(match_ratios) # Get the highest matching score
#         if max_ratio >= 70:
#             input_hot_song = hot.song[match_ratios.index(max_ratio)] # Correct the input by the song which matches the input best
#             check_singer = hot.loc[hot.song.str.lower() == input_hot_song.lower(), 'artist'][0]
#             comfirm_hot_artist = input(f'Do you mean "{input_hot_song}" performed by "{check_singer}"? (Y/N) ')
            
#             if comfirm_hot_artist.lower() == 'y':
#                 print(f'Got it! Playing "{input_hot_song}" performed by "{check_singer}"!')
#                 display(play_song(find_track_id(input_hot_song, check_singer))) # Play the song
                
#                 # Recommend another hot song and play it
#                 rec_hot = random.sample(hot.song.tolist(), k=1)[0]
#                 rec_hot_request = input(f'Would you like to try another hot song: "{rec_hot}"? (Y/N)')
#                 if rec_hot_request.lower() == 'y':
#                     rec_hot_singer = hot_split.loc[hot_split.song.str.lower() == rec_hot.lower(), 'artist_1'].iloc[0]
#                     print(f'Wonderful! Playing "{rec_hot}" performed by "{rec_hot_singer}"!')
#                     display(play_song(find_track_id(rec_hot, rec_hot_singer)))
#                     print(f'Thank you for using GrooveGenie!')
#                     break
#                 elif rec_hot_request.lower() == 'n':
#                     print(f'No problem! Thank you for using GrooveGenie!')
#                     break
#                 else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
                    
#             # Recommend another song depending on the audio features        
#             elif comfirm_hot_artist.lower() == 'n':
#                 # Let user to choose a possible artist and play it accordingly
#                 other_artists_list = other_artists(input_song, check_singer)
#                 print(f'No problem! Is the song performed by one of the following artists: {list_with_number(other_artists_list)}?')
#                 choose_artist = input(f'If the artist is listed, please input the number to choose; otherwise please input "N".')
#                 if choose_artist.lower() == 'n':
#                     print(f'I am sorry, the song you entered might not be found.')
#                     continue
#                 elif choose_artist.isdigit() and int(choose_artist) in range(1, len(other_artists_list)):
#                     chosen_artist = other_artists_list[int(choose_artist) - 1]
#                     chosen_track_id = find_track_id(input_song, chosen_artist)
#                     chosen_track_name = find_track_name(chosen_track_id)
#                     print(f'Got it! Playing "{chosen_track_name}" performed by "{chosen_artist}".')
#                     display(play_song(chosen_track_id))
                    
#                     # Ask user if want to listen another song
#                     rec_other_request = input(f'Would you like to try another song like this one: "{chosen_track_name}"? (Y/N)')
                    
#                     if rec_other_request.lower() == 'y':
#                         chosen_track_features_df = get_sound_features(chosen_track_id)
#                         chosen_track_label = cluster_label(chosen_track_features_df)
#                         rec_other_id = rec_sample_id(chosen_track_label)
#                         rec_other_name = find_track_name(rec_other_id)
#                         rec_other_artist = find_track_artist(rec_other_id)

#                         print(f'Wonderful! Playing "{rec_other_name}" performed by "{rec_other_artist}"!')
#                         display(play_song(rec_other_id))
#                         print(f'Thank you for using GrooveGenie!')
#                         break
#                     elif rec_hot_request.lower() == 'n':
#                         print(f'No problem! Thank you for using GrooveGenie!')
#                         break
#                     else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')

#                 else: 
#                     print(f'Please enter a number between 1 and {len(other_artists_list)} or letter "N" (for "No").')
#                     # Loose end!!! This won't send user back to 'choose_artist' input
                
#             else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
#         else:
#             # Play the input song out of the hot list
#             input_track_id = find_track_id_first(input_song)
#             input_track_name = find_track_name(input_track_id)
#             input_track_artist = find_track_artist(input_track_id)
#             print(f'Got it! Playing "{input_track_name}" performed by "{input_track_artist}".')
#             display(play_song(input_track_id))
            
            
#             rec_hot = random.sample(hot.song.tolist(), k=5)
#             print(f'Sorry, this is not a hot song. Would you like to try one of these hot songs? {rec_hot}')

# %%
# # Feature: Let user to choose the track name and artist    

# def GrooveGenie():
#     while True:
#         input_song = input('Please enter a song: ')
#         match_ratios = [fuzz.token_set_ratio(input_song.lower(), s.lower()) for s in hot.song] # Generate a list of matching scores
#         max_ratio = max(match_ratios) # Get the highest matching score
#         if max_ratio >= 70:
#             input_hot_song = hot.song[match_ratios.index(max_ratio)] # Correct the input by the song which matches the input best
#             check_singer = hot.loc[hot.song.str.lower() == input_hot_song.lower(), 'artist'].iloc[0]
#             comfirm_hot_artist = input(f'Do you mean "{input_hot_song}" performed by "{check_singer}"? (Y/N) ')
            
#             if comfirm_hot_artist.lower() == 'y':
#                 print(f'Got it! Playing "{input_hot_song}" performed by "{check_singer}"!')
#                 display(play_song(find_track_id(input_hot_song, check_singer))) # Play the song
                
#                 # Recommend another hot song and play it
#                 rec_hot = random.sample(hot.song.tolist(), k=1)[0]
#                 rec_hot_request = input(f'Would you like to try another hot song: "{rec_hot}"? (Y/N)')
#                 if rec_hot_request.lower() == 'y':
#                     rec_hot_singer = hot_split.loc[hot_split.song.str.lower() == rec_hot.lower(), 'artist_1'].iloc[0]
#                     print(f'Wonderful! Playing "{rec_hot}" performed by "{rec_hot_singer}"!')
#                     rec_hot_track_id = find_track_id(rec_hot, rec_hot_singer)
#                     display(play_song(rec_hot_track_id))
#                     print(f'Thank you for using GrooveGenie!')
#                     break
#                 elif rec_hot_request.lower() == 'n':
#                     print(f'No problem! Thank you for using GrooveGenie!')
#                     break
#                 else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
                    
#             # Recommend another song depending on the audio features        
#             elif comfirm_hot_artist.lower() == 'n':
#                 # Let user to choose a possible artist and play it accordingly
                
#                 comfirm_track_artist_list, comfirm_artist_list, comfirm_track_list = track_artist_pair(input_song)
                
#                 print(f'Got it! Here is the search result: {comfirm_track_artist_list}')
#                 precise_track = input(f'Please input the number to choose the song you want to listen. To exit please input "X".')
                
#                 if precise_track.lower() == 'x':
#                     print(f'Thank you for using GrooveGenie!')
#                     break
                    
#                 elif precise_track.isdigit() and int(precise_track) in range(1, len(comfirm_track_artist_list)):
#                     comfirm_artist = comfirm_artist_list[int(precise_track) - 1]
#                     comfirm_track_name = comfirm_track_list[int(precise_track) - 1]
#                     comfirm_track_id = find_track_id(comfirm_track_name, comfirm_artist)
#                     print(f'Got it! Playing "{comfirm_track_name}" performed by "{comfirm_artist}".')
#                     display(play_song(comfirm_track_id))
                    
#                     # Ask user if want to listen another song
#                     rec_other_request = input(f'Would you like to try another song like this one: "{comfirm_track_name}"? (Y/N)')
                    
#                     if rec_other_request.lower() == 'y':
#                         chosen_track_features_df = get_sound_features(comfirm_track_id)
#                         chosen_track_label = cluster_label(chosen_track_features_df)
#                         rec_other_id = rec_sample_id(chosen_track_label)
#                         rec_other_name = find_track_name(rec_other_id)
#                         rec_other_artist = find_track_artist(rec_other_id)

#                         print(f'Wonderful! Playing "{rec_other_name}" performed by "{rec_other_artist}"!')
#                         display(play_song(rec_other_id))
#                         print(f'Thank you for using GrooveGenie!')
#                         break
#                     elif rec_hot_request.lower() == 'n':
#                         print(f'No problem! Thank you for using GrooveGenie!')
#                         break
#                     else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')

#                 else: 
#                     print(f'Please enter a number between 1 and {len(other_artists_list)} or letter "N" (for "No").')
#                     # Loose end!!! This won't send user back to 'choose_artist' input
                
#             else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
#         else:
#             # Let user to choose the track name and artist
#             track_artist_list, artist_list, track_list = track_artist_pair(input_song)
#             print(f'Got it! Here is the search result: {track_artist_list}')
#             precise_track = input(f'Please input the number to choose the song you want to listen. To exit please input "X".')
            
#             if precise_track.isdigit() and int(precise_track) in range(1, len(track_artist_list)):
#                 precise_artist = artist_list[int(precise_track) - 1]
#                 precise_track_name = track_list[int(precise_track) - 1]
#                 precise_track_id = find_track_id(precise_track_name, precise_artist)
#                 print(f'Got it! Playing "{precise_track}" performed by "{precise_artist}".')
#                 display(play_song(precise_track_id))            
#             elif precise_track.lower() == 'x':
#                 print(f'Thank you for using GrooveGenie!')
#                 break
#             else:
#                 print(f'Please enter a number between 1 and {len(track_artist_list)} or letter "X" (for "Exit").')

# %%
# # Feature: Recommend another song depending on the audio features of the song out of the hot list    

# def GrooveGenie():
#     while True:
#         input_song = input('Please enter a song: ')
#         match_ratios = [fuzz.token_set_ratio(input_song.lower(), s.lower()) for s in hot.song] # Generate a list of matching scores
#         max_ratio = max(match_ratios) # Get the highest matching score
#         if max_ratio >= 70:
#             input_hot_song = hot.song[match_ratios.index(max_ratio)] # Correct the input by the song which matches the input best
#             check_singer = hot.loc[hot.song.str.lower() == input_hot_song.lower(), 'artist'].iloc[0]
#             comfirm_hot_artist = input(f'Do you mean "{input_hot_song}" performed by "{check_singer}"? (Y/N) ')
            
#             if comfirm_hot_artist.lower() == 'y':
#                 print(f'Got it! Playing "{input_hot_song}" performed by "{check_singer}"!')
#                 display(play_song(find_track_id(input_hot_song, check_singer))) # Play the song
                
#                 # Recommend another hot song and play it
#                 rec_hot = random.sample(hot.song.tolist(), k=1)[0]
#                 rec_hot_request = input(f'Would you like to try another hot song: "{rec_hot}"? (Y/N)')
#                 if rec_hot_request.lower() == 'y':
#                     rec_hot_singer = hot_split.loc[hot_split.song.str.lower() == rec_hot.lower(), 'artist_1'].iloc[0]
#                     print(f'Wonderful! Playing "{rec_hot}" performed by "{rec_hot_singer}"!')
#                     rec_hot_track_id = find_track_id(rec_hot, rec_hot_singer)
#                     display(play_song(rec_hot_track_id))
#                     print(f'Thank you for using GrooveGenie!')
#                     break
#                 elif rec_hot_request.lower() == 'n':
#                     print(f'No problem! Thank you for using GrooveGenie!')
#                     break
#                 else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
                    
#             # Recommend another song depending on the audio features        
#             elif comfirm_hot_artist.lower() == 'n':
#                 # Let user to choose a possible artist and play it accordingly
                
#                 comfirm_track_artist_list, comfirm_artist_list, comfirm_track_list = track_artist_pair(input_song)
                
#                 print(f'Got it! Here is the search result: {comfirm_track_artist_list}')
#                 precise_track = input(f'Please input the number to choose the song you want to listen. To exit please input "X".')
                
#                 if precise_track.lower() == 'x':
#                     print(f'Thank you for using GrooveGenie!')
#                     break
                    
#                 elif precise_track.isdigit() and int(precise_track) in range(1, len(comfirm_track_artist_list)):
#                     comfirm_artist = comfirm_artist_list[int(precise_track) - 1]
#                     comfirm_track_name = comfirm_track_list[int(precise_track) - 1]
#                     comfirm_track_id = find_track_id(comfirm_track_name, comfirm_artist)
#                     print(f'Got it! Playing "{comfirm_track_name}" performed by "{comfirm_artist}".')
#                     display(play_song(comfirm_track_id))
                    
#                     # Recommend another song alike
#                     rec_other_request = input(f'Would you like to try another song like this one: "{comfirm_track_name}"? (Y/N)')
                    
#                     if rec_other_request.lower() == 'y':
#                         chosen_track_features_df = get_sound_features(comfirm_track_id)
#                         chosen_track_label = cluster_label(chosen_track_features_df)
#                         rec_other_id = rec_sample_id(chosen_track_label)
#                         rec_other_name = find_track_name(rec_other_id)
#                         rec_other_artist = find_track_artist(rec_other_id)

#                         print(f'Wonderful! Playing "{rec_other_name}" performed by "{rec_other_artist}"!')
#                         display(play_song(rec_other_id))
#                         print(f'Thank you for using GrooveGenie!')
#                         break
                        
#                     elif rec_hot_request.lower() == 'n':
#                         print(f'No problem! Thank you for using GrooveGenie!')
#                         break
                        
#                     else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')

#                 else: 
#                     print(f'Please enter a number between 1 and {len(other_artists_list)} or letter "N" (for "No").')
#                     # Loose end!!! This won't send user back to 'choose_artist' input
                
#             else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
#         else:
#             # Let user to choose the track name and artist
#             track_artist_list, artist_list, track_list = track_artist_pair(input_song)
#             print(f'Got it! Here is the search result: {track_artist_list}')
#             precise_track = input(f'Please input the number to choose the song you want to listen. To exit please input "X".')
            
#             if precise_track.isdigit() and int(precise_track) in range(1, len(track_artist_list)):
#                 precise_artist = artist_list[int(precise_track) - 1]
#                 precise_track_name = track_list[int(precise_track) - 1]
#                 precise_track_id = find_track_id(precise_track_name, precise_artist)
#                 print(f'Got it! Playing "{precise_track}" performed by "{precise_artist}".')
#                 display(play_song(precise_track_id)) 
                
#                 # Recommend another song alike
#                 rec_other_request = input(f'Would you like to try another song like this one: "{precise_track_name}"? (Y/N)')
                
#                 if rec_other_request.lower() == 'y':
#                     chosen_track_features_df = get_sound_features(precise_track_id)
#                     chosen_track_label = cluster_label(chosen_track_features_df)
#                     rec_other_id = rec_sample_id(chosen_track_label)
#                     rec_other_name = find_track_name(rec_other_id)
#                     rec_other_artist = find_track_artist(rec_other_id)

#                     print(f'Wonderful! Playing "{rec_other_name}" performed by "{rec_other_artist}"!')
#                     display(play_song(rec_other_id))
#                     print(f'Thank you for using GrooveGenie!')
#                     break
                    
#                 elif rec_hot_request.lower() == 'n':
#                     print(f'No problem! Thank you for using GrooveGenie!')
#                     break
                    
#                 else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')                
                
#             elif precise_track.lower() == 'x':
#                 print(f'Thank you for using GrooveGenie!')
#                 break
#             else:
#                 print(f'Please enter a number between 1 and {len(track_artist_list)} or letter "X" (for "Exit").')

# %%
# # Feature: Give user an opition to exit in every input    

# def GrooveGenie():
#     while True:
#         input_song = input('Welcome to GrooveGenie! Please enter a song (Note: to exit please always enter "X"): ')
#         match_ratios = [fuzz.token_set_ratio(input_song.lower(), s.lower()) for s in hot.song] # Generate a list of matching scores
#         max_ratio = max(match_ratios) # Get the highest matching score
        
#         if input_song.lower() == 'x':
#             print(f'Thank you for using GrooveGenie!')
#             break
            
#         elif max_ratio >= 80:
#             input_hot_song = hot.song[match_ratios.index(max_ratio)] # Correct the input by the song which matches the input best
#             check_singer = hot.loc[hot.song.str.lower() == input_hot_song.lower(), 'artist'].iloc[0]
#             comfirm_hot_artist = input(f'Do you mean "{input_hot_song}" performed by "{check_singer}"? (Y/N)')
            
#             if comfirm_hot_artist.lower() == 'x':
#                 print(f'Thank you for using GrooveGenie!')
#                 break
                
#             elif comfirm_hot_artist.lower() == 'y':
#                 print(f'Got it! Playing "{input_hot_song}" performed by "{check_singer}"!')
#                 input_hot_song_id = find_track_id_first(input_hot_song)
#                 display(play_song(input_hot_song_id)) # Play the song
                
#                 # Recommend another hot song and play it
#                 rec_hot = random.sample(hot.song.tolist(), k=1)[0]
#                 rec_hot_request = input(f'Would you like to try another hot song: "{rec_hot}"? (Y/N)')
                
#                 if rec_hot_request.lower() == 'x':
#                     print(f'Thank you for using GrooveGenie!')
#                     break                
                
#                 elif rec_hot_request.lower() == 'y':
#                     # rec_hot_singer = hot_split.loc[hot_split.song.str.lower() == rec_hot.lower(), 'artist_1'].iloc[0]
#                     print(f'Wonderful! Playing "{rec_hot}"!')
                    
#                     rec_hot_track_id = find_track_id_first(rec_hot)
#                     display(play_song(rec_hot_track_id))
#                     print(f'Thank you for using GrooveGenie!')
#                     break
                    
#                 elif rec_hot_request.lower() == 'n':
#                     print(f'No problem! Thank you for using GrooveGenie!')
#                     break
                    
#                 else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
                    
#             # Recommend another song depending on the audio features        
#             elif comfirm_hot_artist.lower() == 'n':
#                 # Let user to choose a possible artist and play it accordingly
                
#                 comfirm_track_artist_list, comfirm_artist_list, comfirm_track_list = track_artist_pair(input_song)
                
#                 # display each item in a separate line
#                 comfirm_track_artist_str = '\n'.join(comfirm_track_artist_list)
                
#                 print(f'Got it! Here is the search result: \n{comfirm_track_artist_str}')
#                 precise_track = input(f'Please input the number to choose the song you want to listen.')
                
#                 if precise_track.lower() == 'x':
#                     print(f'Thank you for using GrooveGenie!')
#                     break
                    
#                 elif precise_track.isdigit() and int(precise_track) in range(1, len(comfirm_track_artist_list)):
#                     comfirm_artist = comfirm_artist_list[int(precise_track) - 1]
#                     comfirm_track_name = comfirm_track_list[int(precise_track) - 1]
#                     comfirm_track_id = find_track_id(comfirm_track_name, comfirm_artist)
#                     print(f'Got it! Playing "{comfirm_track_name}" performed by "{comfirm_artist}".')
#                     display(play_song(comfirm_track_id))
                    
#                     # Recommend another song alike
#                     rec_other_request = input(f'Would you like to try another song like this one: "{comfirm_track_name}"? (Y/N)')
                    
#                     if rec_other_request.lower() == 'x':
#                         print(f'Thank you for using GrooveGenie!')
#                         break
                    
#                     elif rec_other_request.lower() == 'y':
#                         chosen_track_features_df = get_sound_features(comfirm_track_id)
#                         chosen_track_label = cluster_label(chosen_track_features_df)
#                         rec_other_id = rec_sample_id(chosen_track_label)
#                         rec_other_name = find_track_name(rec_other_id)
#                         rec_other_artist = find_track_artist(rec_other_id)

#                         print(f'Wonderful! Playing "{rec_other_name}" performed by "{rec_other_artist}"!')
#                         display(play_song(rec_other_id))
#                         print(f'Thank you for using GrooveGenie!')
#                         break
                        
#                     elif rec_hot_request.lower() == 'n':
#                         print(f'No problem! Thank you for using GrooveGenie!')
#                         break
                        
#                     else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')

#                 else: 
#                     print(f'Please enter a number between 1 and {len(other_artists_list)} or letter "N" (for "No").')
#                     # Loose end!!! This won't send user back to 'choose_artist' input
                
#             else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
#         else:
#             # Let user to choose the track name and artist
#             track_artist_list, artist_list, track_list = track_artist_pair(input_song)
            
#             # display each item in a separate line
#             track_artist_str = '\n'.join(track_artist_list)
            
#             print(f'Got it! Here is the search result: \n{track_artist_str}')
#             precise_track = input(f'Please input the number to choose the song you want to listen.')
            
#             if precise_track.lower() == 'x':
#                 print(f'Thank you for using GrooveGenie!')
#                 break
                
#             elif precise_track.isdigit() and int(precise_track) in range(1, len(track_artist_list)):
#                 precise_artist = artist_list[int(precise_track) - 1]
#                 precise_track_name = track_list[int(precise_track) - 1]
#                 precise_track_id = find_track_id(precise_track_name, precise_artist)
#                 print(f'Got it! Playing "{precise_track}" performed by "{precise_artist}".')
#                 display(play_song(precise_track_id)) 
                
#                 # Recommend another song alike
#                 rec_other_request = input(f'Would you like to try another song like this one: "{precise_track_name}"? (Y/N)')
            
#                 if rec_other_request.lower() == 'x':
#                     print(f'Thank you for using GrooveGenie!')
#                     break
                
#                 elif rec_other_request.lower() == 'y':
#                     chosen_track_features_df = get_sound_features(precise_track_id)
#                     chosen_track_label = cluster_label(chosen_track_features_df)
#                     rec_other_id = rec_sample_id(chosen_track_label)
#                     rec_other_name = find_track_name(rec_other_id)
#                     rec_other_artist = find_track_artist(rec_other_id)

#                     print(f'Wonderful! Playing "{rec_other_name}" performed by "{rec_other_artist}"!')
#                     display(play_song(rec_other_id))
#                     print(f'Thank you for using GrooveGenie!')
#                     break
                    
#                 elif rec_hot_request.lower() == 'n':
#                     print(f'No problem! Thank you for using GrooveGenie!')
#                     break
                    
#                 else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')                
                
#             elif precise_track.lower() == 'x':
#                 print(f'Thank you for using GrooveGenie!')
#                 break
#             else:
#                 print(f'Please enter a number between 1 and {len(track_artist_list)} or letter "X" (for "Exit").')

# %%
# Feature: add while loops to provide the option to request input again if the input is not valid    

def GrooveGenie():
    while True:
        input_song = input('Welcome to GrooveGenie! Please enter a song (Note: to exit please always enter "X"): ')
        match_ratios = [fuzz.token_set_ratio(input_song.lower(), s.lower()) for s in hot.song] # Generate a list of matching scores
        max_ratio = max(match_ratios) # Get the highest matching score
        
        if input_song.lower() == 'x':
            print(f'Thank you for using GrooveGenie!')
            break
            
        elif max_ratio >= 80:
            input_hot_song = hot.song[match_ratios.index(max_ratio)] # Correct the input by the song which matches the input best
            check_singer = hot.loc[hot.song.str.lower() == input_hot_song.lower(), 'artist'].iloc[0]
            while True:
                comfirm_hot_artist = input(f'Do you mean "{input_hot_song}" performed by "{check_singer}"? (Y/N)')

                if comfirm_hot_artist.lower() == 'x':
                    print(f'Thank you for using GrooveGenie!')
                    break

                elif comfirm_hot_artist.lower() == 'y':
                    print(f'Got it! Playing "{input_hot_song}" performed by "{check_singer}"!')
                    input_hot_song_id = find_track_id_first(input_hot_song)
                    display(play_song(input_hot_song_id)) # Play the song

                    # Recommend another hot song and play it
                    rec_hot = random.sample(hot.song.tolist(), k=1)[0]
                    while True:
                        rec_hot_request = input(f'Would you like to try another hot song: "{rec_hot}"? (Y/N)')

                        if rec_hot_request.lower() == 'x':
                            print(f'Thank you for using GrooveGenie!')
                            break                

                        elif rec_hot_request.lower() == 'y':
                            # rec_hot_singer = hot_split.loc[hot_split.song.str.lower() == rec_hot.lower(), 'artist_1'].iloc[0]
                            print(f'Wonderful! Playing "{rec_hot}"!')

                            rec_hot_track_id = find_track_id_first(rec_hot)
                            display(play_song(rec_hot_track_id))
                            print(f'Thank you for using GrooveGenie!')
                            break

                        elif rec_hot_request.lower() == 'n':
                            print(f'No problem! Thank you for using GrooveGenie!')
                            break

                        else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
                        break    
                    break

                # Recommend another song depending on the audio features        
                elif comfirm_hot_artist.lower() == 'n':
                    # Let user to choose a possible artist and play it accordingly

                    comfirm_track_artist_list, comfirm_artist_list, comfirm_track_list = track_artist_pair(input_song)

                    # display each item in a separate line
                    comfirm_track_artist_str = '\n'.join(comfirm_track_artist_list)

                    print(f'Got it! Here is the search result: \n{comfirm_track_artist_str}')
                    
                    while True:
                        precise_track = input('Please enter the number to choose the song you want to listen. ')

                        if precise_track.lower() == 'x':
                            print(f'Thank you for using GrooveGenie!')
                            break

                        elif precise_track.isdigit() and int(precise_track) in range(1, len(comfirm_track_artist_list)+1): # +1 because range() is exclusive
                            comfirm_artist = comfirm_artist_list[int(precise_track) - 1]
                            comfirm_track_name = comfirm_track_list[int(precise_track) - 1]
                            comfirm_track_id = find_track_id(comfirm_track_name, comfirm_artist)
                            print(f'Got it! Playing "{comfirm_track_name}" performed by "{comfirm_artist}".')
                            display(play_song(comfirm_track_id))

                            # Recommend another song alike
                            while True:
                                rec_other_request = input(f'Would you like to try another song like this one? (Y/N) ')

                                if rec_other_request.lower() == 'x':
                                    print(f'Thank you for using GrooveGenie!')
                                    break

                                elif rec_other_request.lower() == 'y':
                                    chosen_track_features_df = get_sound_features(comfirm_track_id)
                                    chosen_track_label = cluster_label(chosen_track_features_df)
                                    rec_other_id = rec_sample_id(chosen_track_label)
                                    rec_other_name = find_track_name(rec_other_id)
                                    rec_other_artist = find_track_artist(rec_other_id)

                                    print(f'Wonderful! Playing "{rec_other_name}" performed by "{rec_other_artist}"!')
                                    display(play_song(rec_other_id))
                                    print(f'Thank you for using GrooveGenie!')
                                    break

                                elif rec_other_request.lower() == 'n':
                                    print(f'No problem! Thank you for using GrooveGenie!')
                                    break

                                else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
                                break
                            break

                        else: 
                            print(f'Please enter a number between 1 and {len(other_artists_list)} or letter "N" (for "No").')
                        break
                    break

                else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
                break    
            break
            
        else:
            # Let user to choose the track name and artist
            track_artist_list, artist_list, track_list = track_artist_pair(input_song)
            
            # display each item in a separate line
            track_artist_str = '\n'.join(track_artist_list)
            
            print(f'Got it! Here is the search result: \n{track_artist_str}')
            
            while True:
                precise_track = input(f'Please input the number to choose the song you want to listen.')

                if precise_track.lower() == 'x':
                    print(f'Thank you for using GrooveGenie!')
                    break

                elif precise_track.isdigit() and int(precise_track) in range(1, len(track_artist_list)+1):
                    precise_artist = artist_list[int(precise_track) - 1]
                    precise_track_name = track_list[int(precise_track) - 1]
                    precise_track_id = find_track_id(precise_track_name, precise_artist)
                    print(f'Got it! Playing "{precise_track}" performed by "{precise_artist}".')
                    display(play_song(precise_track_id)) 

                    # Recommend another song alike
                    while True:
                        rec_other_request = input(f'Would you like to try another song like this one: "{precise_track_name}"? (Y/N)')

                        if rec_other_request.lower() == 'x':
                            print(f'Thank you for using GrooveGenie!')
                            break

                        elif rec_other_request.lower() == 'y':
                            chosen_track_features_df = get_sound_features(precise_track_id)
                            chosen_track_label = cluster_label(chosen_track_features_df)
                            rec_other_id = rec_sample_id(chosen_track_label)
                            rec_other_name = find_track_name(rec_other_id)
                            rec_other_artist = find_track_artist(rec_other_id)

                            print(f'Wonderful! Playing "{rec_other_name}" performed by "{rec_other_artist}"!')
                            display(play_song(rec_other_id))
                            print(f'Thank you for using GrooveGenie!')
                            break

                        elif rec_other_request.lower() == 'n':
                            print(f'No problem! Thank you for using GrooveGenie!')
                            break

                        else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
                        break
                    break

                elif precise_track.lower() == 'x':
                    print(f'Thank you for using GrooveGenie!')
                    break
                else:
                    print(f'Please enter a number between 1 and {len(track_artist_list)} or letter "X" (for "Exit").')
                break
            break

# %%
# # Feature: offer the option to search another song at the end of a task   

# def GrooveGenie():
#     while True:
#         input_song = input('Welcome to GrooveGenie! Please enter a song (Note: to exit please always enter "X"): ')
#         match_ratios = [fuzz.token_set_ratio(input_song.lower(), s.lower()) for s in hot.song] # Generate a list of matching scores
#         max_ratio = max(match_ratios) # Get the highest matching score
        
#         if input_song.lower() == 'x':
#             print(f'Thank you for using GrooveGenie!')
#             break
            
#         elif max_ratio >= 80:
#             input_hot_song = hot.song[match_ratios.index(max_ratio)] # Correct the input by the song which matches the input best
#             check_singer = hot.loc[hot.song.str.lower() == input_hot_song.lower(), 'artist'].iloc[0]
#             while True:
#                 comfirm_hot_artist = input(f'Do you mean "{input_hot_song}" performed by "{check_singer}"? (Y/N)')

#                 if comfirm_hot_artist.lower() == 'x':
#                     print(f'Thank you for using GrooveGenie!')
#                     break

#                 elif comfirm_hot_artist.lower() == 'y':
#                     print(f'Got it! Playing "{input_hot_song}" performed by "{check_singer}"!')
#                     input_hot_song_id = find_track_id_first(input_hot_song)
#                     display(play_song(input_hot_song_id)) # Play the song

#                     # Recommend another hot song and play it
#                     rec_hot = random.sample(hot.song.tolist(), k=1)[0]
#                     while True:
#                         rec_hot_request = input(f'Would you like to try another hot song: "{rec_hot}"? (Y/N)')

#                         if rec_hot_request.lower() == 'x':
#                             print(f'Thank you for using GrooveGenie!')
#                             break                

#                         elif rec_hot_request.lower() == 'y':
#                             # rec_hot_singer = hot_split.loc[hot_split.song.str.lower() == rec_hot.lower(), 'artist_1'].iloc[0]
#                             print(f'Wonderful! Playing "{rec_hot}"!')

#                             rec_hot_track_id = find_track_id_first(rec_hot)
#                             display(play_song(rec_hot_track_id))
#                             break

#                         elif rec_hot_request.lower() == 'n':
#                             print(f'No problem! Thank you for using GrooveGenie!')
#                             break

#                         else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
#                         break    
#                     break

#                 # Recommend another song depending on the audio features        
#                 elif comfirm_hot_artist.lower() == 'n':
#                     # Let user to choose a possible artist and play it accordingly

#                     comfirm_track_artist_list, comfirm_artist_list, comfirm_track_list = track_artist_pair(input_song)

#                     # display each item in a separate line
#                     comfirm_track_artist_str = '\n'.join(comfirm_track_artist_list)

#                     print(f'Got it! Here is the search result: \n{comfirm_track_artist_str}')
                    
#                     while True:
#                         precise_track = input(f'Please input the number to choose the song you want to listen. ')

#                         if precise_track.lower() == 'x':
#                             print(f'Thank you for using GrooveGenie!')
#                             break

#                         elif precise_track.isdigit() and int(precise_track) in range(1, len(comfirm_track_artist_list)+1):
#                             comfirm_artist = comfirm_artist_list[int(precise_track) - 1]
#                             comfirm_track_name = comfirm_track_list[int(precise_track) - 1]
#                             comfirm_track_id = find_track_id(comfirm_track_name, comfirm_artist)
#                             print(f'Got it! Playing "{comfirm_track_name}" performed by "{comfirm_artist}".')
#                             display(play_song(comfirm_track_id))

#                             # Recommend another song alike
#                             while True:
#                                 rec_other_request = input(f'Would you like to try another song like this one: "{comfirm_track_name}"? (Y/N)')

#                                 if rec_other_request.lower() == 'x':
#                                     print(f'Thank you for using GrooveGenie!')
#                                     break

#                                 elif rec_other_request.lower() == 'y':
#                                     chosen_track_features_df = get_sound_features(comfirm_track_id)
#                                     chosen_track_label = cluster_label(chosen_track_features_df)
#                                     rec_other_id = rec_sample_id(chosen_track_label)
#                                     rec_other_name = find_track_name(rec_other_id)
#                                     rec_other_artist = find_track_artist(rec_other_id)

#                                     print(f'Wonderful! Playing "{rec_other_name}" performed by "{rec_other_artist}"!')
#                                     display(play_song(rec_other_id))
#                                     break

#                                 elif rec_hot_request.lower() == 'n':
#                                     print(f'No problem! Thank you for using GrooveGenie!')
#                                     break

#                                 else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
#                                 break
#                             break

#                         else: 
#                             print(f'Please enter a number between 1 and {len(other_artists_list)} or letter "N" (for "No").')
#                         break
#                     break

#                 else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
#                 break    
#             break
            
#         else:
#             # Let user to choose the track name and artist
#             track_artist_list, artist_list, track_list = track_artist_pair(input_song)
            
#             # display each item in a separate line
#             track_artist_str = '\n'.join(track_artist_list)
            
#             print(f'Got it! Here is the search result: \n{track_artist_str}')
            
#             while True:
#                 precise_track = input(f'Please input the number to choose the song you want to listen.')

#                 if precise_track.lower() == 'x':
#                     print(f'Thank you for using GrooveGenie!')
#                     break

#                 elif precise_track.isdigit() and int(precise_track) in range(1, len(track_artist_list)):
#                     precise_artist = artist_list[int(precise_track) - 1]
#                     precise_track_name = track_list[int(precise_track) - 1]
#                     precise_track_id = find_track_id(precise_track_name, precise_artist)
#                     print(f'Got it! Playing "{precise_track}" performed by "{precise_artist}".')
#                     display(play_song(precise_track_id)) 

#                     # Recommend another song alike
#                     while True:
#                         rec_other_request = input(f'Would you like to try another song like this one: "{precise_track_name}"? (Y/N)')

#                         if rec_other_request.lower() == 'x':
#                             print(f'Thank you for using GrooveGenie!')
#                             break

#                         elif rec_other_request.lower() == 'y':
#                             chosen_track_features_df = get_sound_features(precise_track_id)
#                             chosen_track_label = cluster_label(chosen_track_features_df)
#                             rec_other_id = rec_sample_id(chosen_track_label)
#                             rec_other_name = find_track_name(rec_other_id)
#                             rec_other_artist = find_track_artist(rec_other_id)

#                             print(f'Wonderful! Playing "{rec_other_name}" performed by "{rec_other_artist}"!')
#                             display(play_song(rec_other_id))
#                             break

#                         elif rec_other_request.lower() == 'n':
#                             print(f'No problem! Thank you for using GrooveGenie!')
#                             break

#                         else: print(f'Please enter a letter "Y" (for "Yes") or "N" (for "No").')
#                         break
#                     break

#                 elif precise_track.lower() == 'x':
#                     print(f'Thank you for using GrooveGenie!')
#                     break
#                 else:
#                     print(f'Please enter a number between 1 and {len(track_artist_list)}.')
#                 break
                
#             # offer the option to search another song at the end of a task
#             while True:
#                 search_again = input('Would you like to search another song? (Y/N) ')

#                 if search_again.lower() == 'y':
#                     print('Great! Here you go!')
#                     break 

#                 elif search_again.lower() in ['x', 'n']:
#                     print('Thank you for using GrooveGenie!')
#                     break

#                 else :
#                     print('Please enter a letter "Y" (for "Yes") or "N" (for "No").')
#                     continue

# %%
GrooveGenie()
# Out:
# Welcome to GrooveGenie! Please enter a song (Note: to exit please always enter "X"): perfect
# Got it! Here is the search result:
# 1. Perfect - Ed Sheeran
# 2. Perfect - Acoustic - Ed Sheeran
# 3. Perfect - One Direction
# 4. Perfect - Ed Sheeran
# 5. Perfect Day - Lou Reed
# 6. Perfect Duet (Ed Sheeran & Beyoncé) - Ed Sheeran
# 7. Perfect Natural White Noise as a Relaxing Ambient Sleep Aid (Nice Lullaby) - White Noise Baby Sleep
# 8. Perfect - Ed Sheeran
# 9. the perfect pair - beabadoobee
# 10. Perfect Strangers - Jonas Blue
# Please input the number to choose the song you want to listen.1
# Got it! Playing "1" performed by "Ed Sheeran".
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/1DHTfk8FwmWNzSh1nLmkRS?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Would you like to try another song like this one: "Perfect"? (Y/N)y
# Wonderful! Playing "Ain't Like That" performed by "Baby Stone Gorillas"!
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/5sm3g5UwuDnzKN91T5elip?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Thank you for using GrooveGenie!

# %%
playlists = sp.user_playlists('spotify')
while playlists:
    for i, playlist in enumerate(playlists['items']):
        print("%4d %s %s" % (i + 1 + playlists['offset'], playlist['id'],  playlist['name']))
    if playlists['next']:
        playlists = sp.next(playlists)
    else:
        playlists = None
# Out:
#    1 37i9dQZF1DXcBWIGoYBM5M Today's Top Hits
#    2 37i9dQZF1DX0XUsuxWHRQd RapCaviar
#    3 37i9dQZF1DX1lVhptIYRda Hot Country
