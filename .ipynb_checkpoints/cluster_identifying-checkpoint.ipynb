# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score## Loading credentials from another config file

# %% [markdown]
# ## Loading credentials from another config file

# %%
import config

# %% [markdown]
# ## Starting with Spotify API

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %% [markdown]
# ## Searching the song input by user

# %%
user_song = 'Perfect'

# %%
results = sp.search(q = user_song, limit = 3, market="GB")
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Perfect&type=track&market=GB&offset=0&limit=3',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#      'href': 'https://api.spotify.com/v1/albums/3T4tUhGYeRNVUGevb0wThu',
#      'id': '3T4tUhGYeRNVUGevb0wThu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ba5db46f4b838ef6027e6f96',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ba5db46f4b838ef6027e6f96',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ba5db46f4b838ef6027e6f96',
#        'width': 64}],
#      'name': '÷ (Deluxe)',
#      'release_date': '2017-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:3T4tUhGYeRNVUGevb0wThu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 263400,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1700024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0tgVpDi06FyKpA1z0VMD4v'},
#     'href': 'https://api.spotify.com/v1/tracks/0tgVpDi06FyKpA1z0VMD4v',
#     'id': '0tgVpDi06FyKpA1z0VMD4v',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect',
#     'popularity': 85,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a929516d1cc57de66ae18e7d02d0673147a305d9?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0tgVpDi06FyKpA1z0VMD4v'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4uJ318DIOMiA4y9vg2dRwv'},
#      'href': 'https://api.spotify.com/v1/albums/4uJ318DIOMiA4y9vg2dRwv',
#      'id': '4uJ318DIOMiA4y9vg2dRwv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a629dbc92d4dcb0312b45fa2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a629dbc92d4dcb0312b45fa2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a629dbc92d4dcb0312b45fa2',
#        'width': 64}],
#      'name': 'Perfect (Acoustic)',
#      'release_date': '2017-11-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4uJ318DIOMiA4y9vg2dRwv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 260866,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1701083'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5T6bJp3XgwT0IaCfKMxmAu'},
#     'href': 'https://api.spotify.com/v1/tracks/5T6bJp3XgwT0IaCfKMxmAu',
#     'id': '5T6bJp3XgwT0IaCfKMxmAu',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect - Acoustic',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5d910d6a3f3452133f818ca90f4ccc025cd2b39d?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5T6bJp3XgwT0IaCfKMxmAu'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6g6NVjkCHREmXuV8R4m9Wu'},
#      'href': 'https://api.spotify.com/v1/albums/6g6NVjkCHREmXuV8R4m9Wu',
#      'id': '6g6NVjkCHREmXuV8R4m9Wu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c12abd69bce7cde233015421',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c12abd69bce7cde233015421',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c12abd69bce7cde233015421',
#        'width': 64}],
#      'name': 'Jerusalema: Modern Hits',
#      'release_date': '2023-02-15',
#      'release_date_precision': 'day',
#      'total_tracks': 60,
#      'type': 'album',
#      'uri': 'spotify:album:6g6NVjkCHREmXuV8R4m9Wu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 263400,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1700024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2U012DLF3DvfBEsVvNqbVd'},
#     'href': 'https://api.spotify.com/v1/tracks/2U012DLF3DvfBEsVvNqbVd',
#     'id': '2U012DLF3DvfBEsVvNqbVd',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Perfect',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9f56c08eb8c921458e9c92d1104b45f8b4ac1408?cid=48e86a1397024724b0581c60871cc44e',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2U012DLF3DvfBEsVvNqbVd'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=Perfect&type=track&market=GB&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 1000}}

# %%
# Identify artist
user_song_artist = results['tracks']['items'][0]['artists'][0]['name']

# %%
# Identify track ID
user_song_id = results['tracks']['items'][0]['id']

# %%
# Get audio features of this song
user_song_features = sp.audio_features(tracks=[user_song_id])

# %%
# Save the features in a dataframe
user_song_raw_df = pd.DataFrame(user_song_features)
user_song_df = user_song_raw_df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","duration_ms"]]
user_song_df
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.599   0.448    -6.312       0.0232         0.163
#
#    instrumentalness  liveness  valence  tempo  duration_ms
# 0                 0     0.106    0.168  95.05       263400

# %% [markdown]
# ## Applying Model

# %% [markdown]
# ## Doading Dataset

# %%
X = pd.read_csv('data/playlists.csv')

# %%
X
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.707   0.681    -4.325       0.0668       0.06320
# 1            0.644   0.735    -5.747       0.0391       0.05210
# 2            0.696   0.809    -8.254       0.0500       0.25200
# 3            0.538   0.742    -5.355       0.1140       0.13800
# 4            0.662   0.398    -6.691       0.0275       0.71600
# ...            ...     ...       ...          ...           ...
# 2418         0.636   0.656    -7.123       0.3440       0.02190
# 2419         0.753   0.424   -10.620       0.5990       0.19700
# 2420         0.501   0.699    -4.733       0.2480       0.17100
# 2421         0.645   0.842    -3.023       0.0983       0.00816
# 2422         0.902   0.544    -8.242       0.2420       0.15300
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000005    0.0322    0.646  117.999  0yLdNVWF3Srea0uzk55zFn
# 1             0.144000    0.1610    0.418   88.980  1Qrg8KqiBpW07V7PNxwwwL
# 2             0.000128    0.2480    0.857  132.962  6AQbmUe0Qwf5PZnt4HmTXv
# 3             0.000047    0.0934    0.250   96.107  5Z2MiIZ5I3jJvvmeWMLbOQ
# 4             0.000000    0.1110    0.468  107.001  4sx6NRwL6Ol3V6m9exwGlQ
# ...                ...       ...      ...      ...                     ...
# 2418          0.000000    0.1300    0.362   75.962  2nLwnTorexhx3qKRY7zymH
# 2419          0.000000    0.0694    0.714  162.878  5ckdswsm7RQzCTBoNiyl7T
# 2420          0.000000    0.1230    0.671   85.267  7rGzPK1JTUn91efeiIidNo
# 2421          0.000000    0.3960    0.237  150.039  2kMuUWfsueRPYWxyaTSHd8
# 2422          0.000000    0.1110    0.136  131.912  7b4LMdMrjPLNUNwxO46sQR
#
#       duration_ms
# 0          200455
# 1          153947
# 2          131013
# 3          272373
# 4          145850
# ...           ...
# 2418       177012
# 2419       100180
# 2420       201124
# 2421       121600
# 2422       160000
#
# [2423 rows x 11 columns]

# %%
# Extract numerical cols
X_num = X.select_dtypes(include=['float64', 'int64'])

# %%
X_num
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.707   0.681    -4.325       0.0668       0.06320
# 1            0.644   0.735    -5.747       0.0391       0.05210
# 2            0.696   0.809    -8.254       0.0500       0.25200
# 3            0.538   0.742    -5.355       0.1140       0.13800
# 4            0.662   0.398    -6.691       0.0275       0.71600
# ...            ...     ...       ...          ...           ...
# 2418         0.636   0.656    -7.123       0.3440       0.02190
# 2419         0.753   0.424   -10.620       0.5990       0.19700
# 2420         0.501   0.699    -4.733       0.2480       0.17100
# 2421         0.645   0.842    -3.023       0.0983       0.00816
# 2422         0.902   0.544    -8.242       0.2420       0.15300
#
#       instrumentalness  liveness  valence    tempo  duration_ms
# 0             0.000005    0.0322    0.646  117.999       200455
# 1             0.144000    0.1610    0.418   88.980       153947
# 2             0.000128    0.2480    0.857  132.962       131013
# 3             0.000047    0.0934    0.250   96.107       272373
# 4             0.000000    0.1110    0.468  107.001       145850
# ...                ...       ...      ...      ...          ...
# 2418          0.000000    0.1300    0.362   75.962       177012
# 2419          0.000000    0.0694    0.714  162.878       100180
# 2420          0.000000    0.1230    0.671   85.267       201124
# 2421          0.000000    0.3960    0.237  150.039       121600
# 2422          0.000000    0.1110    0.136  131.912       160000
#
# [2423 rows x 10 columns]

# %% [markdown]
# ## Scaling features

# %%
scaler = StandardScaler()
scaler.fit(X_num)
X_scaled = scaler.transform(X_num)
X_scaled_df = pd.DataFrame(X_scaled, columns = X_num.columns)
display(X_num.head())
print()
display(X_scaled_df.head())
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.707   0.681    -4.325       0.0668        0.0632
# 1         0.644   0.735    -5.747       0.0391        0.0521
# 2         0.696   0.809    -8.254       0.0500        0.2520
# 3         0.538   0.742    -5.355       0.1140        0.1380
# 4         0.662   0.398    -6.691       0.0275        0.7160
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000005    0.0322    0.646  117.999       200455
# 1          0.144000    0.1610    0.418   88.980       153947
# 2          0.000128    0.2480    0.857  132.962       131013
# 3          0.000047    0.0934    0.250   96.107       272373
# 4          0.000000    0.1110    0.468  107.001       145850
#    danceability    energy  loudness  speechiness  acousticness  \
# 0      0.596043  0.433025  0.774695    -0.334403     -0.787999
# 1      0.228609  0.635469  0.585278    -0.574993     -0.819821
# 2      0.531888  0.912893  0.251333    -0.480320     -0.246737
# 3     -0.389612  0.661712  0.637494     0.075556     -0.573558
# 4      0.333590 -0.627934  0.459532    -0.675745      1.083483
#
#    instrumentalness  liveness   valence     tempo  duration_ms
# 0         -0.448685 -1.051603  0.552641 -0.025989    -0.005247
# 1          0.002294 -0.029185 -0.365433 -1.011085    -0.778662
# 2         -0.448300  0.661424  1.402261  0.481953    -1.160048
# 3         -0.448555 -0.565795 -1.041908 -0.769147     1.190730
# 4         -0.448701 -0.426086 -0.164101 -0.399334    -0.913313

# %% [markdown]
# # Clustering the tracks with K-Means

# %%
kmeans = KMeans(n_clusters = 6, random_state = 1234)
kmeans.fit(X_scaled_df)
# Out:
# KMeans(n_clusters=6, random_state=1234)

# %%
kmeans.labels_
# Out:
# array([5, 5, 5, ..., 3, 4, 3], dtype=int32)

# %%
# assign a cluster to each example
labels = kmeans.predict(X_scaled_df)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(X.to_numpy()[row_ix, 1], X.to_numpy()[row_ix, 3])
# show the plot
pyplot.show()

# %% [markdown]
# ## Identify Cluster of User's Song

# %%
# Scale features of user song
user_scaled = scaler.transform(user_song_df)
user_scaled_df = pd.DataFrame(user_scaled, columns = user_song_df.columns)
user_scaled_df
# Out:
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -0.033843 -0.440486  0.510017    -0.713093     -0.501887
#
#    instrumentalness  liveness   valence     tempo  duration_ms
# 0         -0.448701 -0.465776 -1.372093 -0.805029     1.041512

# %%
# Get the cluster label of user song
user_cluster = kmeans.predict(user_scaled_df)

user_cluster_num = user_cluster[0]

# %% [markdown]
# ## Choosing a Song from the Identified Cluster

# %%
X_clustered = pd.read_csv('data/playlists_clustered.csv')

# %%
X_clustered
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.707   0.681    -4.325       0.0668       0.06320
# 1            0.644   0.735    -5.747       0.0391       0.05210
# 2            0.696   0.809    -8.254       0.0500       0.25200
# 3            0.538   0.742    -5.355       0.1140       0.13800
# 4            0.662   0.398    -6.691       0.0275       0.71600
# ...            ...     ...       ...          ...           ...
# 2418         0.636   0.656    -7.123       0.3440       0.02190
# 2419         0.753   0.424   -10.620       0.5990       0.19700
# 2420         0.501   0.699    -4.733       0.2480       0.17100
# 2421         0.645   0.842    -3.023       0.0983       0.00816
# 2422         0.902   0.544    -8.242       0.2420       0.15300
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000005    0.0322    0.646  117.999  0yLdNVWF3Srea0uzk55zFn
# 1             0.144000    0.1610    0.418   88.980  1Qrg8KqiBpW07V7PNxwwwL
# 2             0.000128    0.2480    0.857  132.962  6AQbmUe0Qwf5PZnt4HmTXv
# 3             0.000047    0.0934    0.250   96.107  5Z2MiIZ5I3jJvvmeWMLbOQ
# 4             0.000000    0.1110    0.468  107.001  4sx6NRwL6Ol3V6m9exwGlQ
# ...                ...       ...      ...      ...                     ...
# 2418          0.000000    0.1300    0.362   75.962  2nLwnTorexhx3qKRY7zymH
# 2419          0.000000    0.0694    0.714  162.878  5ckdswsm7RQzCTBoNiyl7T
# 2420          0.000000    0.1230    0.671   85.267  7rGzPK1JTUn91efeiIidNo
# 2421          0.000000    0.3960    0.237  150.039  2kMuUWfsueRPYWxyaTSHd8
# 2422          0.000000    0.1110    0.136  131.912  7b4LMdMrjPLNUNwxO46sQR
#
#       duration_ms  cluster
# 0          200455        5
# 1          153947        5
# 2          131013        5
# 3          272373        2
# 4          145850        0
# ...           ...      ...
# 2418       177012        3
# 2419       100180        3
# 2420       201124        3
# 2421       121600        4
# 2422       160000        3
#
# [2423 rows x 12 columns]

# %%
import random
# Filter out rows where cluster == user_cluster_num
rec_df = X_clustered[X_clustered['cluster'] == user_cluster_num]

# %%
rec_df
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 3            0.538   0.742    -5.355       0.1140      0.138000
# 9            0.714   0.472    -7.375       0.0864      0.013000
# 15           0.486   0.545    -7.924       0.0336      0.065200
# 16           0.559   0.551    -7.231       0.1320      0.141000
# 25           0.587   0.742    -6.640       0.0529      0.012800
# ...            ...     ...       ...          ...           ...
# 2332         0.719   0.655    -4.519       0.0999      0.202000
# 2344         0.762   0.634    -6.790       0.1260      0.073700
# 2386         0.834   0.730    -3.714       0.2220      0.005130
# 2403         0.729   0.625    -5.266       0.0315      0.194000
# 2413         0.477   0.727    -4.053       0.2860      0.000866
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 3             0.000047    0.0934   0.2500   96.107  5Z2MiIZ5I3jJvvmeWMLbOQ
# 9             0.000005    0.2660   0.2380  131.121  3nqQXoyQOWXiESFLlDF1hG
# 15            0.004740    0.0642   0.0385  150.187  4FyesJzVpA39hbYvcseO2d
# 16            0.000000    0.1100   0.3920  143.008  4iZ4pt7kvcaH6Yo8UoZ4s2
# 25            0.001070    0.1460   0.1990  145.007  73vIOb4Q7YN6HeJTbscRx5
# ...                ...       ...      ...      ...                     ...
# 2332          0.000000    0.1570   0.2380  125.925  6QC19cMrtbLNrZMH2bVl7w
# 2344          0.000000    0.0758   0.2080   93.127  5sm3g5UwuDnzKN91T5elip
# 2386          0.000000    0.1240   0.4460  155.008  2xLMifQCjDGFmkHkpNLD9h
# 2403          0.009860    0.2480   0.2610  146.034  1xzBco0xcoJEDXktl7Jxrr
# 2413          0.000000    0.1080   0.2270  150.062  1EJIcDYXwSqipW5dFe4uJz
#
#       duration_ms  cluster
# 3          272373        2
# 9          156943        2
# 15         123891        2
# 16         201800        2
# 25         206000        2
# ...           ...      ...
# 2332       233226        2
# 2344       247742        2
# 2386       312820        2
# 2403       183907        2
# 2413       236524        2
#
# [454 rows x 12 columns]

# %%
import random
# Randomly select one row from the filtered DataFrame
rec_row = filtered_df.sample(random_state=1)

# %%
rec_id = X_clustered[X_clustered['cluster'] == user_cluster_num].sample()['id'].values[0]
rec_id
# Out:
# '1Ud6moTC0KyXMq1Oxfien0'

# %% [markdown]
# ## Embeded track player

# %% [markdown]
# {'spotify': https://open.spotify.com/track/4O2N861eOnF9q8EtpH8IJu

# %%
from IPython.display import IFrame

def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
play_song(rec_id)
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/2RaA6kIcvomt77qlIgGhCT?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
